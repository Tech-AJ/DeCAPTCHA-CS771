# %%
import pandas as pd
import numpy as np
import cv2 as cv
import glob
import imutils
from imutils import paths
import os
import os.path

# %%
for filename in os.listdir('train'):
    img = cv.imread('train/'+filename,-1)
    hsv = cv.cvtColor(img, cv.COLOR_BGR2HSV)
    lower_red = np.array([0,0,150])
    upper_red = np.array([255,255,255])
    
    mask = cv.inRange(hsv, lower_red, upper_red)
    #res = cv.bitwise_and(img,img,mask=mask)
    #blured = cv.blur(gray, (5,5), 0) 
    #img_thresh = cv.adaptiveThreshold(mask, 255, cv.ADAPTIVE_THRESH_GAUSSIAN_C, cv.THRESH_BINARY_INV, 11, 2)
#     contours,hierarchy= cv.findContours(mask, cv.RETR_EXTERNAL, cv.CHAIN_APPROX_NONE)
    imCopy = mask.copy()
    imCopy=~imCopy
    #res = cv.bitwise_and(img,img,mask=mask)
    #blured = cv.blur(gray, (5,5), 0) 
    #edged = cv.Canny(mask, 30, 200) 
    #cv.waitKey(0) 
    contours,hierarchy= cv.findContours(imCopy, cv.RETR_EXTERNAL, cv.CHAIN_APPROX_NONE)[-2:]
#     cv.drawContours(mask, contours, -1, (255, 255, 0), 3)    
    #cv2.imshow('contour', img)
    print(filename+" no. of char:"+str(len(contours)))
    cv.imwrite('train2/'+filename,mask)
# Out:
# AAA.png no. of char:3
# AAE.png no. of char:3
# AAGL.png no. of char:4
# AAQI.png no. of char:4
# AAR.png no. of char:3
# ABJG.png no. of char:4
# ABU.png no. of char:3
# ACA.png no. of char:3
# ACD.png no. of char:3
# ACF.png no. of char:3
# ACI.png no. of char:3
# ACKZ.png no. of char:4
# ACN.png no. of char:3
# ACW.png no. of char:3
# ACWT.png no. of char:4
# ADB.png no. of char:3
# ADTX.png no. of char:4
# ADVV.png no. of char:4
# ADY.png no. of char:3
# AEDC.png no. of char:4
# AEIK.png no. of char:4
# AFD.png no. of char:3
# AFLI.png no. of char:4
# AFU.png no. of char:3
# AGIA.png no. of char:4
# AGQ.png no. of char:3
# AGZF.png no. of char:4
# AHCD.png no. of char:4
# AHLD.png no. of char:4
# AHMC.png no. of char:4
# AING.png no. of char:4
# AIPO.png no. of char:4
# AISL.png no. of char:4
# AJGG.png no. of char:4
# AJMN.png no. of char:4
# AJOX.png no. of char:4
# ALBS.png no. of char:4
# ALZM.png no. of char:4
# AMG.png no. of char:3
# AMI.png no. of char:3
# AML.png no. of char:3
# ANDB.png no. of char:4
# ANHL.png no. of char:4
# ANJ.png no. of char:3
# ANMH.png no. of char:4
# ANVB.png no. of char:4
# APE.png no. of char:3
# APHK.png no. of char:4
# APQO.png no. of char:4
# APRQ.png no. of char:4
# AQLE.png no. of char:4
# AQO.png no. of char:3
# AQVU.png no. of char:4
# ARFQ.png no. of char:4
# ARI.png no. of char:3
# ARQ.png no. of char:3
# ARWT.png no. of char:4
# ASBH.png no. of char:4
# ASX.png no. of char:3
# ASXC.png no. of char:4
# ASXG.png no. of char:4
# ASYK.png no. of char:4
# ATK.png no. of char:3
# ATZ.png no. of char:3
# AUCS.png no. of char:4
# AUK.png no. of char:3
# AUYK.png no. of char:4
# AVEO.png no. of char:4
# AVFR.png no. of char:4
# AVR.png no. of char:3
# AVXS.png no. of char:4
# AWB.png no. of char:3
# AWI.png no. of char:3
# AWS.png no. of char:3
# AWVY.png no. of char:4
# AXAK.png no. of char:4
# AXAX.png no. of char:4
# AXL.png no. of char:3
# AXLM.png no. of char:4
# AYDQ.png no. of char:4
# AYF.png no. of char:3
# AYG.png no. of char:3
# AYMM.png no. of char:4
# AYSJ.png no. of char:4
# AZTP.png no. of char:4
# BAB.png no. of char:3
# BAOO.png no. of char:4
# BAS.png no. of char:3
# BAT.png no. of char:3
# BBTB.png no. of char:4
# BCEM.png no. of char:4
# BCQ.png no. of char:3
# BDFP.png no. of char:4
# BDI.png no. of char:3
# BDP.png no. of char:3
# BEA.png no. of char:3
# BEBQ.png no. of char:4
# BEUF.png no. of char:4
# BFAM.png no. of char:4
# BFN.png no. of char:3
# BGM.png no. of char:3
# BGU.png no. of char:3
# BGUB.png no. of char:4
# BGUQ.png no. of char:4
# BGZ.png no. of char:3
# BHAE.png no. of char:4
# BHC.png no. of char:3
# BHLR.png no. of char:4
# BIP.png no. of char:3
# BIS.png no. of char:3
# BIU.png no. of char:3
# BJM.png no. of char:3
# BJQX.png no. of char:4
# BJU.png no. of char:3
# BKB.png no. of char:3
# BKEY.png no. of char:4
# BKG.png no. of char:3
# BKHG.png no. of char:4
# BLFI.png no. of char:4
# BLG.png no. of char:3
# BLN.png no. of char:3
# BLTO.png no. of char:4
# BLUD.png no. of char:4
# BLXL.png no. of char:4
# BLXY.png no. of char:4
# BMA.png no. of char:3
# BMB.png no. of char:3
# BMVP.png no. of char:4
# BNB.png no. of char:3
# BNIC.png no. of char:4
# BNP.png no. of char:3
# BNQW.png no. of char:4
# BOGE.png no. of char:4
# BOMD.png no. of char:4
# BOT.png no. of char:3
# BOZ.png no. of char:3
# BPO.png no. of char:3
# BPX.png no. of char:3
# BQMN.png no. of char:4
# BRHP.png no. of char:4
# BRQR.png no. of char:4
# BRSW.png no. of char:4
# BRTA.png no. of char:4
# BRY.png no. of char:3
# BSE.png no. of char:3
# BSJ.png no. of char:3
# BSM.png no. of char:3
# BSPC.png no. of char:4
# BSW.png no. of char:3
# BTAU.png no. of char:4
# BTSA.png no. of char:4
# BUF.png no. of char:3
# BVAG.png no. of char:4
# BVGY.png no. of char:4
# BVKM.png no. of char:4
# BVR.png no. of char:3
# BWE.png no. of char:3
# BWLN.png no. of char:4
# BWW.png no. of char:3
# BXII.png no. of char:4
# BYF.png no. of char:3
# BYHO.png no. of char:4
# BYP.png no. of char:3
# BYY.png no. of char:3
# BYZ.png no. of char:3
# BZH.png no. of char:3
# BZL.png no. of char:3
# BZS.png no. of char:3
# BZUF.png no. of char:4
# CAPB.png no. of char:4
# CBB.png no. of char:3
# CBSQ.png no. of char:4
# CBX.png no. of char:3
# CCJ.png no. of char:3
# CCWU.png no. of char:4
# CDBN.png no. of char:4
# CDD.png no. of char:3
# CEH.png no. of char:3
# CFC.png no. of char:3
# CFI.png no. of char:3
# CFW.png no. of char:3
# CGC.png no. of char:3
# CGCT.png no. of char:4
# CGDQ.png no. of char:4
# CGE.png no. of char:3
# CHG.png no. of char:3
# CHS.png no. of char:3
# CHYR.png no. of char:4
# CHZ.png no. of char:3
# CIGW.png no. of char:4
# CIPL.png no. of char:4
# CIV.png no. of char:3
# CJF.png no. of char:3
# CJI.png no. of char:3
# CJS.png no. of char:3
# CJU.png no. of char:3
# CKCH.png no. of char:4
# CKD.png no. of char:3
# CKE.png no. of char:3
# CKSZ.png no. of char:4
# CKX.png no. of char:3
# CKZW.png no. of char:4
# CLG.png no. of char:3
# CMI.png no. of char:3
# CMJ.png no. of char:3
# CMJH.png no. of char:4
# CML.png no. of char:3
# CMX.png no. of char:3
# CNH.png no. of char:3
# CNLT.png no. of char:4
# COI.png no. of char:3
# COK.png no. of char:3
# COSJ.png no. of char:4
# COW.png no. of char:3
# CPG.png no. of char:3
# CPL.png no. of char:3
# CPO.png no. of char:3
# CPPO.png no. of char:4
# CPSB.png no. of char:4
# CSB.png no. of char:3
# CSF.png no. of char:3
# CSG.png no. of char:3
# CSWP.png no. of char:4
# CSZ.png no. of char:3
# CTDJ.png no. of char:4
# CUO.png no. of char:3
# CVJW.png no. of char:4
# CVOS.png no. of char:4
# CVTB.png no. of char:4
# CVU.png no. of char:3
# CWG.png no. of char:3
# CWH.png no. of char:3
# CWIK.png no. of char:4
# CWLB.png no. of char:4
# CWTX.png no. of char:4
# CXD.png no. of char:3
# CXDH.png no. of char:4
# CXGJ.png no. of char:4
# CXNR.png no. of char:4
# CXS.png no. of char:3
# CXW.png no. of char:3
# CYG.png no. of char:3
# CZDZ.png no. of char:4
# DAJ.png no. of char:3
# DART.png no. of char:4
# DBBQ.png no. of char:4
# DBRW.png no. of char:4
# DBVX.png no. of char:4
# DCGE.png no. of char:4
# DCMG.png no. of char:4
# DCNW.png no. of char:4
# DCUS.png no. of char:4
# DEHW.png no. of char:4
# DEL.png no. of char:3
# DEM.png no. of char:3
# DEO.png no. of char:3
# DFB.png no. of char:3
# DFC.png no. of char:3
# DFO.png no. of char:3
# DFXK.png no. of char:4
# DFY.png no. of char:3
# DFZ.png no. of char:3
# DGA.png no. of char:3
# DGD.png no. of char:3
# DGUP.png no. of char:4
# DHV.png no. of char:3
# DHXD.png no. of char:4
# DIBZ.png no. of char:4
# DIYG.png no. of char:4
# DJI.png no. of char:3
# DJVA.png no. of char:4
# DKI.png no. of char:3
# DKLD.png no. of char:4
# DKM.png no. of char:3
# DKO.png no. of char:3
# DKUM.png no. of char:4
# DLB.png no. of char:3
# DLCX.png no. of char:4
# DLEB.png no. of char:4
# DLL.png no. of char:3
# DMRX.png no. of char:4
# DNF.png no. of char:3
# DNJ.png no. of char:3
# DNOG.png no. of char:4
# DNPL.png no. of char:4
# DNRV.png no. of char:4
# DOH.png no. of char:3
# DOO.png no. of char:3
# DPU.png no. of char:3
# DPWL.png no. of char:4
# DQC.png no. of char:3
# DQH.png no. of char:3
# DQIP.png no. of char:4
# DQKQ.png no. of char:4
# DQR.png no. of char:3
# DQS.png no. of char:3
# DQWX.png no. of char:4
# DRYI.png no. of char:4
# DSHP.png no. of char:4
# DST.png no. of char:3
# DSXN.png no. of char:4
# DSY.png no. of char:3
# DTWP.png no. of char:4
# DUJ.png no. of char:3
# DUU.png no. of char:3
# DUWO.png no. of char:4
# DUZU.png no. of char:4
# DVA.png no. of char:3
# DVKF.png no. of char:4
# DVQ.png no. of char:3
# DVZN.png no. of char:4
# DWAO.png no. of char:4
# DWWV.png no. of char:4
# DXJH.png no. of char:4
# DXQL.png no. of char:4
# DXV.png no. of char:3
# DYE.png no. of char:3
# DYGG.png no. of char:4
# DYO.png no. of char:3
# DZGJ.png no. of char:4
# DZH.png no. of char:3
# DZP.png no. of char:3
# DZR.png no. of char:3
# EACN.png no. of char:4
# EAE.png no. of char:3
# EAO.png no. of char:3
# EARK.png no. of char:4
# EAS.png no. of char:3
# EAXC.png no. of char:4
# EBC.png no. of char:3
# EBPK.png no. of char:4
# EBUK.png no. of char:4
# ECGH.png no. of char:4
# ECM.png no. of char:3
# EDH.png no. of char:3
# EDI.png no. of char:3
# EDIU.png no. of char:4
# EDMX.png no. of char:4
# EDRI.png no. of char:4
# EDTW.png no. of char:4
# EDV.png no. of char:3
# EDY.png no. of char:3
# EEBE.png no. of char:4
# EEN.png no. of char:3
# EEYK.png no. of char:4
# EEZ.png no. of char:3
# EFGS.png no. of char:4
# EFHN.png no. of char:4
# EFN.png no. of char:3
# EFY.png no. of char:3
# EGD.png no. of char:3
# EGN.png no. of char:3
# EGQY.png no. of char:4
# EGT.png no. of char:3
# EGWX.png no. of char:4
# EGY.png no. of char:3
# EHKH.png no. of char:4
# EHSD.png no. of char:4
# EIK.png no. of char:3
# EIR.png no. of char:3
# EJD.png no. of char:3
# EJH.png no. of char:3
# EJI.png no. of char:3
# EJKV.png no. of char:4
# EJLK.png no. of char:4
# EJT.png no. of char:3
# EJUZ.png no. of char:4
# EKH.png no. of char:3
# EKM.png no. of char:3
# EKX.png no. of char:3
# EMS.png no. of char:3
# ENLD.png no. of char:4
# ENOW.png no. of char:4
# ENQ.png no. of char:3
# ENR.png no. of char:3
# ENSR.png no. of char:4
# ENSU.png no. of char:4
# ENZ.png no. of char:3
# EONP.png no. of char:4
# EOO.png no. of char:3
# EPLY.png no. of char:4
# EPMU.png no. of char:4
# EPOV.png no. of char:4
# EPZU.png no. of char:4
# EQEL.png no. of char:4
# EQHA.png no. of char:4
# EQP.png no. of char:3
# ERJ.png no. of char:3
# ERK.png no. of char:3
# ERPE.png no. of char:4
# ERR.png no. of char:3
# ESD.png no. of char:3
# ESE.png no. of char:3
# ESIW.png no. of char:4
# ESL.png no. of char:3
# ESY.png no. of char:3
# ETGM.png no. of char:4
# ETI.png no. of char:3
# ETO.png no. of char:3
# ETRJ.png no. of char:4
# EUDN.png no. of char:4
# EUS.png no. of char:3
# EUUF.png no. of char:4
# EVCU.png no. of char:4
# EVF.png no. of char:3
# EVI.png no. of char:3
# EVRH.png no. of char:4
# EVRY.png no. of char:4
# EWFH.png no. of char:4
# EWK.png no. of char:3
# EWOA.png no. of char:4
# EWTF.png no. of char:4
# EWUO.png no. of char:4
# EXI.png no. of char:3
# EXPW.png no. of char:4
# EXZG.png no. of char:4
# EYB.png no. of char:3
# EYIZ.png no. of char:4
# EYSL.png no. of char:4
# EYY.png no. of char:3
# EYZ.png no. of char:3
# EZH.png no. of char:3
# EZP.png no. of char:3
# EZS.png no. of char:3
# EZVI.png no. of char:4
# EZVK.png no. of char:4
# EZX.png no. of char:3
# FAP.png no. of char:3
# FAQN.png no. of char:4
# FAW.png no. of char:3
# FBF.png no. of char:3
# FBH.png no. of char:3
# FCCW.png no. of char:4
# FCLV.png no. of char:4
# FCM.png no. of char:3
# FDM.png no. of char:3
# FDPO.png no. of char:4
# FDQL.png no. of char:4
# FEE.png no. of char:3
# FEKD.png no. of char:4
# FEMY.png no. of char:4
# FFKT.png no. of char:4
# FGCT.png no. of char:4
# FGFM.png no. of char:4
# FGI.png no. of char:3
# FHG.png no. of char:3
# FHKN.png no. of char:4
# FHLQ.png no. of char:4
# FHNS.png no. of char:4
# FJCU.png no. of char:4
# FJJW.png no. of char:4
# FJRN.png no. of char:4
# FKI.png no. of char:3
# FKPX.png no. of char:4
# FKR.png no. of char:3
# FLD.png no. of char:3
# FLDG.png no. of char:4
# FLNT.png no. of char:4
# FLTG.png no. of char:4
# FMID.png no. of char:4
# FMO.png no. of char:3
# FMQN.png no. of char:4
# FNTV.png no. of char:4
# FOJ.png no. of char:3
# FOXE.png no. of char:4
# FOZL.png no. of char:4
# FPOU.png no. of char:4
# FQIV.png no. of char:4
# FRL.png no. of char:3
# FSD.png no. of char:3
# FSMF.png no. of char:4
# FSRH.png no. of char:4
# FTCS.png no. of char:4
# FUBO.png no. of char:4
# FUC.png no. of char:3
# FUW.png no. of char:3
# FUYH.png no. of char:4
# FVJI.png no. of char:4
# FVN.png no. of char:3
# FVSP.png no. of char:4
# FVVB.png no. of char:4
# FVX.png no. of char:3
# FWB.png no. of char:3
# FWI.png no. of char:3
# FWT.png no. of char:3
# FWW.png no. of char:3
# FWXT.png no. of char:4
# FWY.png no. of char:3
# FXA.png no. of char:3
# FXP.png no. of char:3
# FXR.png no. of char:3
# FXS.png no. of char:3
# FXXU.png no. of char:4
# FYA.png no. of char:3
# FYB.png no. of char:3
# FYEF.png no. of char:4
# FYFZ.png no. of char:4
# FYHE.png no. of char:4
# FZF.png no. of char:3
# FZP.png no. of char:3
# FZPA.png no. of char:4
# FZUR.png no. of char:4
# FZW.png no. of char:3
# GAD.png no. of char:3
# GAN.png no. of char:3
# GBRO.png no. of char:4
# GBUF.png no. of char:4
# GCA.png no. of char:3
# GCI.png no. of char:3
# GCRU.png no. of char:4
# GCVJ.png no. of char:4
# GDFN.png no. of char:4
# GDHQ.png no. of char:4
# GDNE.png no. of char:4
# GDOJ.png no. of char:4
# GDYV.png no. of char:4
# GEA.png no. of char:3
# GEBD.png no. of char:4
# GEDJ.png no. of char:4
# GEHM.png no. of char:4
# GEI.png no. of char:3
# GEPQ.png no. of char:4
# GEXI.png no. of char:4
# GFUV.png no. of char:4
# GFVR.png no. of char:4
# GFZ.png no. of char:3
# GGPK.png no. of char:4
# GGRI.png no. of char:4
# GGSP.png no. of char:4
# GGXP.png no. of char:4
# GHK.png no. of char:3
# GIC.png no. of char:3
# GIK.png no. of char:3
# GIMC.png no. of char:4
# GIMN.png no. of char:4
# GIX.png no. of char:3
# GJA.png no. of char:3
# GJG.png no. of char:3
# GJIU.png no. of char:4
# GJMV.png no. of char:4
# GJNA.png no. of char:4
# GKB.png no. of char:3
# GKO.png no. of char:3
# GKP.png no. of char:3
# GKVQ.png no. of char:4
# GLCG.png no. of char:4
# GLG.png no. of char:3
# GLI.png no. of char:3
# GMMU.png no. of char:4
# GMO.png no. of char:3
# GMRK.png no. of char:4
# GMVC.png no. of char:4
# GNBJ.png no. of char:4
# GNHB.png no. of char:4
# GNS.png no. of char:3
# GOG.png no. of char:3
# GOS.png no. of char:3
# GOWW.png no. of char:4
# GPNN.png no. of char:4
# GPQP.png no. of char:4
# GQPA.png no. of char:4
# GQWB.png no. of char:4
# GSG.png no. of char:3
# GSOP.png no. of char:4
# GSSJ.png no. of char:4
# GSV.png no. of char:3
# GTS.png no. of char:3
# GUAV.png no. of char:4
# GUEX.png no. of char:4
# GUL.png no. of char:3
# GUSV.png no. of char:4
# GUZA.png no. of char:4
# GVBX.png no. of char:4
# GVQ.png no. of char:3
# GVRE.png no. of char:4
# GWBY.png no. of char:4
# GWVG.png no. of char:4
# GWZI.png no. of char:4
# GYD.png no. of char:3
# GYF.png no. of char:3
# GYG.png no. of char:3
# GYKW.png no. of char:4
# GYU.png no. of char:3
# GYX.png no. of char:3
# GYY.png no. of char:3
# GYZ.png no. of char:3
# GZF.png no. of char:3
# GZO.png no. of char:3
# GZSN.png no. of char:4
# GZY.png no. of char:3
# HAUC.png no. of char:4
# HBDV.png no. of char:4
# HBNI.png no. of char:4
# HBNP.png no. of char:4
# HBNV.png no. of char:4
# HBOR.png no. of char:4
# HBU.png no. of char:3
# HCHX.png no. of char:4
# HCSQ.png no. of char:4
# HCZ.png no. of char:3
# HDNW.png no. of char:4
# HDOH.png no. of char:4
# HDOO.png no. of char:4
# HDP.png no. of char:3
# HDR.png no. of char:3
# HDZL.png no. of char:4
# HDZW.png no. of char:4
# HEA.png no. of char:3
# HEB.png no. of char:3
# HEHM.png no. of char:4
# HEL.png no. of char:3
# HEO.png no. of char:3
# HEPH.png no. of char:4
# HEPO.png no. of char:4
# HEZ.png no. of char:3
# HFD.png no. of char:3
# HFDI.png no. of char:4
# HFM.png no. of char:3
# HGFX.png no. of char:4
# HGG.png no. of char:3
# HGK.png no. of char:3
# HGLN.png no. of char:4
# HHA.png no. of char:3
# HHC.png no. of char:3
# HHI.png no. of char:3
# HHO.png no. of char:3
# HID.png no. of char:3
# HJI.png no. of char:3
# HKL.png no. of char:3
# HKO.png no. of char:3
# HKYP.png no. of char:4
# HLH.png no. of char:3
# HLO.png no. of char:3
# HLR.png no. of char:3
# HNBT.png no. of char:4
# HOB.png no. of char:3
# HOJ.png no. of char:3
# HOQR.png no. of char:4
# HOTI.png no. of char:4
# HPGB.png no. of char:4
# HPJU.png no. of char:4
# HPL.png no. of char:3
# HPLY.png no. of char:4
# HPU.png no. of char:3
# HPYF.png no. of char:4
# HQAR.png no. of char:4
# HQD.png no. of char:3
# HQI.png no. of char:3
# HRI.png no. of char:3
# HROO.png no. of char:4
# HRW.png no. of char:3
# HRWY.png no. of char:4
# HRZT.png no. of char:4
# HSD.png no. of char:3
# HTC.png no. of char:3
# HTS.png no. of char:3
# HTZ.png no. of char:3
# HUS.png no. of char:3
# HUW.png no. of char:3
# HUX.png no. of char:3
# HVAB.png no. of char:4
# HVI.png no. of char:3
# HVP.png no. of char:3
# HWJM.png no. of char:4
# HWLL.png no. of char:4
# HWN.png no. of char:3
# HXMO.png no. of char:4
# HXV.png no. of char:3
# HYJ.png no. of char:3
# HYJX.png no. of char:4
# HYLV.png no. of char:4
# HYSO.png no. of char:4
# HZEA.png no. of char:4
# HZKQ.png no. of char:4
# HZKX.png no. of char:4
# HZPZ.png no. of char:4
# IAE.png no. of char:3
# IAF.png no. of char:3
# IAXY.png no. of char:4
# IBE.png no. of char:3
# IBID.png no. of char:4
# IBUJ.png no. of char:4
# ICB.png no. of char:3
# ICD.png no. of char:3
# ICSZ.png no. of char:4
# ICZ.png no. of char:3
# IDDD.png no. of char:4
# IDRN.png no. of char:4
# IDVJ.png no. of char:4
# IEA.png no. of char:3
# IEO.png no. of char:3
# IFOA.png no. of char:4
# IFTW.png no. of char:4
# IFWZ.png no. of char:4
# IFX.png no. of char:3
# IFXW.png no. of char:4
# IGCM.png no. of char:4
# IGWM.png no. of char:4
# IIC.png no. of char:3
# IJDS.png no. of char:4
# IJH.png no. of char:3
# IJIV.png no. of char:4
# IJSJ.png no. of char:4
# IJU.png no. of char:3
# IKE.png no. of char:3
# IKP.png no. of char:3
# IKWP.png no. of char:4
# ILSE.png no. of char:4
# ILY.png no. of char:3
# IMYJ.png no. of char:4
# INU.png no. of char:3
# INUD.png no. of char:4
# IOA.png no. of char:3
# IOB.png no. of char:3
# IOCD.png no. of char:4
# IODJ.png no. of char:4
# IOF.png no. of char:3
# IOIZ.png no. of char:4
# IOK.png no. of char:3
# IOKG.png no. of char:4
# IOLQ.png no. of char:4
# IOMG.png no. of char:4
# IPH.png no. of char:3
# IPKE.png no. of char:4
# IPME.png no. of char:4
# IPOJ.png no. of char:4
# IQBL.png no. of char:4
# IQEV.png no. of char:4
# IQIY.png no. of char:4
# IQW.png no. of char:3
# IRFH.png no. of char:4
# IRGW.png no. of char:4
# IROX.png no. of char:4
# IRQU.png no. of char:4
# IRVX.png no. of char:4
# IRZ.png no. of char:3
# ISJ.png no. of char:3
# ISJT.png no. of char:4
# ISK.png no. of char:3
# ISXL.png no. of char:4
# ITRM.png no. of char:4
# ITV.png no. of char:3
# IUBA.png no. of char:4
# IUI.png no. of char:3
# IUX.png no. of char:3
# IUZ.png no. of char:3
# IVQ.png no. of char:3
# IWR.png no. of char:3
# IXD.png no. of char:3
# IXJD.png no. of char:4
# IXR.png no. of char:3
# IXVE.png no. of char:4
# IZJ.png no. of char:3
# IZLN.png no. of char:4
# IZT.png no. of char:3
# JCNA.png no. of char:4
# JCRI.png no. of char:4
# JCVC.png no. of char:4
# JDU.png no. of char:3
# JEBN.png no. of char:4
# JER.png no. of char:3
# JEZ.png no. of char:3
# JFIT.png no. of char:4
# JGA.png no. of char:3
# JGNE.png no. of char:4
# JGO.png no. of char:3
# JGQG.png no. of char:4
# JGR.png no. of char:3
# JGXR.png no. of char:4
# JHM.png no. of char:3
# JHR.png no. of char:3
# JHVD.png no. of char:4
# JIJY.png no. of char:4
# JIMI.png no. of char:4
# JIMT.png no. of char:4
# JIQR.png no. of char:4
# JIY.png no. of char:3
# JJDT.png no. of char:4
# JJH.png no. of char:3
# JJRG.png no. of char:4
# JKE.png no. of char:3
# JLC.png no. of char:3
# JLIV.png no. of char:4
# JLMD.png no. of char:4
# JME.png no. of char:3
# JNK.png no. of char:3
# JNPW.png no. of char:4
# JNU.png no. of char:3
# JNXF.png no. of char:4
# JOZ.png no. of char:3
# JPK.png no. of char:3
# JPM.png no. of char:3
# JPRO.png no. of char:4
# JPV.png no. of char:3
# JPVK.png no. of char:4
# JQH.png no. of char:3
# JQP.png no. of char:3
# JQVW.png no. of char:4
# JRP.png no. of char:3
# JSC.png no. of char:3
# JSD.png no. of char:3
# JSMS.png no. of char:4
# JSW.png no. of char:3
# JTVO.png no. of char:4
# JUNJ.png no. of char:4
# JVN.png no. of char:3
# JWHZ.png no. of char:4
# JWIU.png no. of char:4
# JWL.png no. of char:3
# JWVH.png no. of char:4
# JXCJ.png no. of char:4
# JXCO.png no. of char:4
# JYA.png no. of char:3
# JYB.png no. of char:3
# JYUO.png no. of char:4
# JZH.png no. of char:3
# JZRG.png no. of char:4
# JZX.png no. of char:3
# KACD.png no. of char:4
# KAE.png no. of char:3
# KAF.png no. of char:3
# KAP.png no. of char:3
# KAT.png no. of char:3
# KAU.png no. of char:3
# KBF.png no. of char:3
# KBHZ.png no. of char:4
# KBON.png no. of char:4
# KCJ.png no. of char:3
# KCSK.png no. of char:4
# KDEJ.png no. of char:4
# KDIA.png no. of char:4
# KDLM.png no. of char:4
# KDSK.png no. of char:4
# KEEL.png no. of char:4
# KEFL.png no. of char:4
# KEKP.png no. of char:4
# KFDN.png no. of char:4
# KFRZ.png no. of char:4
# KFVF.png no. of char:4
# KFY.png no. of char:3
# KGA.png no. of char:3
# KGKX.png no. of char:4
# KGUN.png no. of char:4
# KHA.png no. of char:3
# KHDC.png no. of char:4
# KHN.png no. of char:3
# KIM.png no. of char:3
# KIPS.png no. of char:4
# KIT.png no. of char:3
# KIV.png no. of char:3
# KIWI.png no. of char:4
# KJBE.png no. of char:4
# KJRC.png no. of char:4
# KLDQ.png no. of char:4
# KLHA.png no. of char:4
# KLK.png no. of char:3
# KLPQ.png no. of char:4
# KLUE.png no. of char:4
# KLVO.png no. of char:4
# KNDN.png no. of char:4
# KOC.png no. of char:3
# KODQ.png no. of char:4
# KOGM.png no. of char:4
# KOIB.png no. of char:4
# KOIK.png no. of char:4
# KOOO.png no. of char:4
# KOXA.png no. of char:4
# KPKM.png no. of char:4
# KQEP.png no. of char:4
# KQFM.png no. of char:4
# KQH.png no. of char:3
# KQV.png no. of char:3
# KQVP.png no. of char:4
# KRQ.png no. of char:3
# KRS.png no. of char:3
# KRU.png no. of char:3
# KRUJ.png no. of char:4
# KRV.png no. of char:3
# KSF.png no. of char:3
# KSJ.png no. of char:3
# KSRL.png no. of char:4
# KSS.png no. of char:3
# KTAL.png no. of char:4
# KUG.png no. of char:3
# KUI.png no. of char:3
# KUNG.png no. of char:4
# KVJ.png no. of char:3
# KVOX.png no. of char:4
# KVSN.png no. of char:4
# KVYQ.png no. of char:4
# KWCG.png no. of char:4
# KWM.png no. of char:3
# KWOF.png no. of char:4
# KWS.png no. of char:3
# KWZX.png no. of char:4
# KXK.png no. of char:3
# KXKB.png no. of char:4
# KXT.png no. of char:3
# KXV.png no. of char:3
# KXY.png no. of char:3
# KXYB.png no. of char:4
# KXYH.png no. of char:4
# KXZ.png no. of char:3
# KYZ.png no. of char:3
# KZB.png no. of char:3
# KZGK.png no. of char:4
# KZN.png no. of char:3
# KZO.png no. of char:3
# KZZY.png no. of char:4
# LAC.png no. of char:3
# LACN.png no. of char:4
# LAWJ.png no. of char:4
# LBD.png no. of char:3
# LBL.png no. of char:3
# LBUH.png no. of char:4
# LBX.png no. of char:3
# LBXX.png no. of char:4
# LCH.png no. of char:3
# LCKZ.png no. of char:4
# LCWF.png no. of char:4
# LDEV.png no. of char:4
# LDH.png no. of char:3
# LDHD.png no. of char:4
# LDHP.png no. of char:4
# LDJU.png no. of char:4
# LDMT.png no. of char:4
# LDWY.png no. of char:4
# LDYN.png no. of char:4
# LDZ.png no. of char:3
# LEJ.png no. of char:3
# LEP.png no. of char:3
# LEUR.png no. of char:4
# LEZ.png no. of char:3
# LFH.png no. of char:3
# LFR.png no. of char:3
# LFUC.png no. of char:4
# LGB.png no. of char:3
# LGG.png no. of char:3
# LGQM.png no. of char:4
# LGX.png no. of char:3
# LGZI.png no. of char:4
# LHH.png no. of char:3
# LHJ.png no. of char:3
# LHSX.png no. of char:4
# LHZH.png no. of char:4
# LIA.png no. of char:3
# LIE.png no. of char:3
# LIQ.png no. of char:3
# LITS.png no. of char:4
# LJF.png no. of char:3
# LJQS.png no. of char:4
# LKWW.png no. of char:4
# LLA.png no. of char:3
# LLB.png no. of char:3
# LLEK.png no. of char:4
# LLU.png no. of char:3
# LMA.png no. of char:3
# LME.png no. of char:3
# LMS.png no. of char:3
# LNFL.png no. of char:4
# LNG.png no. of char:3
# LNV.png no. of char:3
# LOWM.png no. of char:4
# LOX.png no. of char:3
# LOYD.png no. of char:4
# LPR.png no. of char:3
# LQDS.png no. of char:4
# LQE.png no. of char:3
# LQII.png no. of char:4
# LQX.png no. of char:3
# LRL.png no. of char:3
# LRMB.png no. of char:4
# LRV.png no. of char:3
# LRY.png no. of char:3
# LSR.png no. of char:3
# LSUO.png no. of char:4
# LSV.png no. of char:3
# LSXM.png no. of char:4
# LTOT.png no. of char:4
# LTOU.png no. of char:4
# LTW.png no. of char:3
# LUCE.png no. of char:4
# LUP.png no. of char:3
# LUS.png no. of char:3
# LVHX.png no. of char:4
# LVJ.png no. of char:3
# LVL.png no. of char:3
# LWBQ.png no. of char:4
# LWD.png no. of char:3
# LWKK.png no. of char:4
# LWM.png no. of char:3
# LXG.png no. of char:3
# LXH.png no. of char:3
# LYBB.png no. of char:4
# LYCG.png no. of char:4
# LYHV.png no. of char:4
# LYL.png no. of char:3
# LYM.png no. of char:3
# LYO.png no. of char:3
# LYZ.png no. of char:3
# LZBL.png no. of char:4
# LZGI.png no. of char:4
# LZQE.png no. of char:4
# LZWE.png no. of char:4
# MAJZ.png no. of char:4
# MAM.png no. of char:3
# MAMY.png no. of char:4
# MAQB.png no. of char:4
# MAYQ.png no. of char:4
# MAZD.png no. of char:4
# MBF.png no. of char:3
# MBRY.png no. of char:4
# MCPH.png no. of char:4
# MCT.png no. of char:3
# MDA.png no. of char:3
# MDB.png no. of char:3
# MDJ.png no. of char:3
# MDN.png no. of char:3
# MDP.png no. of char:3
# MDZ.png no. of char:3
# MDZQ.png no. of char:4
# MEL.png no. of char:3
# MEM.png no. of char:3
# MEMB.png no. of char:4
# MFBL.png no. of char:4
# MFD.png no. of char:3
# MFT.png no. of char:3
# MFW.png no. of char:3
# MGR.png no. of char:3
# MHO.png no. of char:3
# MHRB.png no. of char:4
# MIL.png no. of char:3
# MIT.png no. of char:3
# MIZH.png no. of char:4
# MJFF.png no. of char:4
# MJFQ.png no. of char:4
# MJJ.png no. of char:3
# MJNU.png no. of char:4
# MJT.png no. of char:3
# MJU.png no. of char:3
# MJW.png no. of char:3
# MJZ.png no. of char:3
# MKQI.png no. of char:4
# MKQZ.png no. of char:4
# MKVT.png no. of char:4
# MKZF.png no. of char:4
# MLAF.png no. of char:4
# MLB.png no. of char:3
# MLF.png no. of char:3
# MMGY.png no. of char:4
# MMOW.png no. of char:4
# MNC.png no. of char:3
# MNXE.png no. of char:4
# MNZ.png no. of char:3
# MOA.png no. of char:3
# MOCN.png no. of char:4
# MOL.png no. of char:3
# MOPK.png no. of char:4
# MOXR.png no. of char:4
# MPG.png no. of char:3
# MQJ.png no. of char:3
# MQJP.png no. of char:4
# MRHC.png no. of char:4
# MRZ.png no. of char:3
# MSVM.png no. of char:4
# MTAI.png no. of char:4
# MTK.png no. of char:3
# MUAO.png no. of char:4
# MUJI.png no. of char:4
# MUP.png no. of char:3
# MVAZ.png no. of char:4
# MVD.png no. of char:3
# MVIF.png no. of char:4
# MVKF.png no. of char:4
# MVW.png no. of char:3
# MWB.png no. of char:3
# MWO.png no. of char:3
# MWZ.png no. of char:3
# MXNY.png no. of char:4
# MXPR.png no. of char:4
# MXWG.png no. of char:4
# MXY.png no. of char:3
# MYC.png no. of char:3
# MYJ.png no. of char:3
# MYK.png no. of char:3
# MYL.png no. of char:3
# MYMH.png no. of char:4
# MYOE.png no. of char:4
# MYQP.png no. of char:4
# MZBI.png no. of char:4
# MZKT.png no. of char:4
# MZU.png no. of char:3
# NAO.png no. of char:3
# NBI.png no. of char:3
# NBMR.png no. of char:4
# NBP.png no. of char:3
# NCCV.png no. of char:4
# NCV.png no. of char:3
# NDU.png no. of char:3
# NEF.png no. of char:3
# NEIK.png no. of char:4
# NELU.png no. of char:4
# NEO.png no. of char:3
# NEZ.png no. of char:3
# NFBC.png no. of char:4
# NFN.png no. of char:3
# NFQ.png no. of char:3
# NFS.png no. of char:3
# NFT.png no. of char:3
# NHG.png no. of char:3
# NIQQ.png no. of char:4
# NIS.png no. of char:3
# NIX.png no. of char:3
# NIZK.png no. of char:4
# NJFX.png no. of char:4
# NJKQ.png no. of char:4
# NJWT.png no. of char:4
# NKL.png no. of char:3
# NKLN.png no. of char:4
# NKV.png no. of char:3
# NKY.png no. of char:3
# NLC.png no. of char:3
# NLG.png no. of char:3
# NLJC.png no. of char:4
# NLO.png no. of char:3
# NLP.png no. of char:3
# NLPV.png no. of char:4
# NLRN.png no. of char:4
# NMUH.png no. of char:4
# NMUM.png no. of char:4
# NMWV.png no. of char:4
# NNB.png no. of char:3
# NNP.png no. of char:3
# NOA.png no. of char:3
# NOE.png no. of char:3
# NOF.png no. of char:3
# NOIY.png no. of char:4
# NON.png no. of char:3
# NOP.png no. of char:3
# NPBM.png no. of char:4
# NPM.png no. of char:3
# NPNB.png no. of char:4
# NPNT.png no. of char:4
# NQBG.png no. of char:4
# NQSP.png no. of char:4
# NQT.png no. of char:3
# NRA.png no. of char:3
# NRDN.png no. of char:4
# NSKT.png no. of char:4
# NSQ.png no. of char:3
# NSZ.png no. of char:3
# NTL.png no. of char:3
# NUDB.png no. of char:4
# NUN.png no. of char:3
# NUQ.png no. of char:3
# NVB.png no. of char:3
# NVBR.png no. of char:4
# NVH.png no. of char:3
# NVPD.png no. of char:4
# NVXH.png no. of char:4
# NWD.png no. of char:3
# NXDS.png no. of char:4
# NXO.png no. of char:3
# NYN.png no. of char:3
# NYRY.png no. of char:4
# NZJL.png no. of char:4
# NZX.png no. of char:3
# OADO.png no. of char:4
# OAKO.png no. of char:4
# OAN.png no. of char:3
# OAT.png no. of char:3
# OAY.png no. of char:3
# OBIA.png no. of char:4
# OBN.png no. of char:3
# OBTH.png no. of char:4
# OCCM.png no. of char:4
# OCD.png no. of char:3
# OCEI.png no. of char:4
# OCGD.png no. of char:4
# OCGN.png no. of char:4
# OCNJ.png no. of char:4
# OCS.png no. of char:3
# ODJ.png no. of char:3
# OEO.png no. of char:3
# OEOA.png no. of char:4
# OEPH.png no. of char:4
# OEU.png no. of char:3
# OEX.png no. of char:3
# OFNB.png no. of char:4
# OFRZ.png no. of char:4
# OGAH.png no. of char:4
# OGKI.png no. of char:4
# OGQD.png no. of char:4
# OGX.png no. of char:3
# OHHW.png no. of char:4
# OHP.png no. of char:3
# OHS.png no. of char:3
# OHT.png no. of char:3
# OHZC.png no. of char:4
# OIBB.png no. of char:4
# OIDT.png no. of char:4
# OIH.png no. of char:3
# OIM.png no. of char:3
# OIS.png no. of char:3
# OIXU.png no. of char:4
# OJC.png no. of char:3
# OJD.png no. of char:3
# OJI.png no. of char:3
# OJM.png no. of char:3
# OKDD.png no. of char:4
# OKG.png no. of char:3
# OLD.png no. of char:3
# OLGL.png no. of char:4
# OLL.png no. of char:3
# OND.png no. of char:3
# ONPK.png no. of char:4
# ONR.png no. of char:3
# ONT.png no. of char:3
# ONU.png no. of char:3
# OOFJ.png no. of char:4
# OOP.png no. of char:3
# OOS.png no. of char:3
# OPIY.png no. of char:4
# OPVG.png no. of char:4
# OQB.png no. of char:3
# OQBA.png no. of char:4
# OQP.png no. of char:3
# OQU.png no. of char:3
# OQW.png no. of char:3
# ORD.png no. of char:3
# ORE.png no. of char:3
# ORKI.png no. of char:4
# ORX.png no. of char:3
# OSZ.png no. of char:3
# OTI.png no. of char:3
# OUO.png no. of char:3
# OUS.png no. of char:3
# OUT.png no. of char:3
# OUUG.png no. of char:4
# OVAZ.png no. of char:4
# OVC.png no. of char:3
# OVM.png no. of char:3
# OVRQ.png no. of char:4
# OVZ.png no. of char:3
# OWFW.png no. of char:4
# OWG.png no. of char:3
# OXKU.png no. of char:4
# OXM.png no. of char:3
# OXN.png no. of char:3
# OXP.png no. of char:3
# OXPU.png no. of char:4
# OXS.png no. of char:3
# OXSS.png no. of char:4
# OXV.png no. of char:3
# OXZ.png no. of char:3
# OYG.png no. of char:3
# OYHU.png no. of char:4
# OYXN.png no. of char:4
# OZLS.png no. of char:4
# OZM.png no. of char:3
# OZSD.png no. of char:4
# PAA.png no. of char:3
# PACK.png no. of char:4
# PAG.png no. of char:3
# PAKI.png no. of char:4
# PARN.png no. of char:4
# PAS.png no. of char:3
# PAVG.png no. of char:4
# PBJ.png no. of char:3
# PBT.png no. of char:3
# PBY.png no. of char:3
# PBZ.png no. of char:3
# PCD.png no. of char:3
# PCQG.png no. of char:4
# PCW.png no. of char:3
# PDIW.png no. of char:4
# PDR.png no. of char:3
# PDXG.png no. of char:4
# PEAN.png no. of char:4
# PEBN.png no. of char:4
# PEEP.png no. of char:4
# PEH.png no. of char:3
# PENM.png no. of char:4
# PESX.png no. of char:4
# PFI.png no. of char:3
# PFNO.png no. of char:4
# PFR.png no. of char:3
# PFU.png no. of char:3
# PFZZ.png no. of char:4
# PGDN.png no. of char:4
# PGG.png no. of char:3
# PGR.png no. of char:3
# PGSJ.png no. of char:4
# PHD.png no. of char:3
# PHIP.png no. of char:4
# PHL.png no. of char:3
# PIG.png no. of char:3
# PIM.png no. of char:3
# PIOO.png no. of char:4
# PIPI.png no. of char:4
# PJCA.png no. of char:4
# PJG.png no. of char:3
# PJGI.png no. of char:4
# PJK.png no. of char:3
# PJLH.png no. of char:4
# PJPB.png no. of char:4
# PJVZ.png no. of char:4
# PJX.png no. of char:3
# PJYZ.png no. of char:4
# PJZA.png no. of char:4
# PKBU.png no. of char:4
# PKFT.png no. of char:4
# PLB.png no. of char:3
# PLFR.png no. of char:4
# PLL.png no. of char:3
# PLT.png no. of char:3
# PLTG.png no. of char:4
# PLWB.png no. of char:4
# PMC.png no. of char:3
# PMQS.png no. of char:4
# PMT.png no. of char:3
# PNJ.png no. of char:3
# PNMF.png no. of char:4
# PNUJ.png no. of char:4
# PNWB.png no. of char:4
# PNWI.png no. of char:4
# POGK.png no. of char:4
# POMH.png no. of char:4
# POUH.png no. of char:4
# POYZ.png no. of char:4
# POZI.png no. of char:4
# PPKG.png no. of char:4
# PQAX.png no. of char:4
# PQD.png no. of char:3
# PQGD.png no. of char:4
# PQKR.png no. of char:4
# PQN.png no. of char:3
# PQWS.png no. of char:4
# PQXA.png no. of char:4
# PRS.png no. of char:3
# PRWO.png no. of char:4
# PRY.png no. of char:3
# PSRC.png no. of char:4
# PSWK.png no. of char:4
# PTCP.png no. of char:4
# PTH.png no. of char:3
# PTQ.png no. of char:3
# PUQ.png no. of char:3
# PUQR.png no. of char:4
# PVRL.png no. of char:4
# PWJF.png no. of char:4
# PWML.png no. of char:4
# PWO.png no. of char:3
# PWUO.png no. of char:4
# PWZ.png no. of char:3
# PXBS.png no. of char:4
# PYBW.png no. of char:4
# PYC.png no. of char:3
# PYEV.png no. of char:4
# PYKV.png no. of char:4
# PYY.png no. of char:3
# PZAY.png no. of char:4
# PZEC.png no. of char:4
# PZI.png no. of char:3
# PZKS.png no. of char:4
# PZQ.png no. of char:3
# PZUB.png no. of char:4
# QAIZ.png no. of char:4
# QARO.png no. of char:4
# QASL.png no. of char:4
# QATM.png no. of char:4
# QBUE.png no. of char:4
# QBZJ.png no. of char:4
# QCO.png no. of char:3
# QCXN.png no. of char:4
# QDA.png no. of char:3
# QDC.png no. of char:3
# QDKT.png no. of char:4
# QDMK.png no. of char:4
# QDN.png no. of char:3
# QDRR.png no. of char:4
# QDSB.png no. of char:4
# QEH.png no. of char:3
# QFS.png no. of char:3
# QGGN.png no. of char:4
# QGL.png no. of char:3
# QGNI.png no. of char:4
# QGNR.png no. of char:4
# QGP.png no. of char:3
# QGQ.png no. of char:3
# QGSA.png no. of char:4
# QGTC.png no. of char:4
# QGU.png no. of char:3
# QGX.png no. of char:3
# QHAO.png no. of char:4
# QHDI.png no. of char:4
# QHE.png no. of char:3
# QHF.png no. of char:3
# QHQ.png no. of char:3
# QHV.png no. of char:3
# QHXC.png no. of char:4
# QIQT.png no. of char:4
# QIZ.png no. of char:3
# QIZL.png no. of char:4
# QKBR.png no. of char:4
# QKEE.png no. of char:4
# QLCT.png no. of char:4
# QLJ.png no. of char:3
# QLYV.png no. of char:4
# QMHZ.png no. of char:4
# QND.png no. of char:3
# QNIZ.png no. of char:4
# QNJ.png no. of char:3
# QNOH.png no. of char:4
# QNP.png no. of char:3
# QNS.png no. of char:3
# QOKZ.png no. of char:4
# QONZ.png no. of char:4
# QOQ.png no. of char:3
# QPAP.png no. of char:4
# QPOU.png no. of char:4
# QPP.png no. of char:3
# QQM.png no. of char:3
# QQO.png no. of char:3
# QQZ.png no. of char:3
# QRGF.png no. of char:4
# QRHT.png no. of char:4
# QRI.png no. of char:3
# QRP.png no. of char:3
# QRWS.png no. of char:4
# QRX.png no. of char:3
# QRY.png no. of char:3
# QTB.png no. of char:3
# QTBZ.png no. of char:4
# QTN.png no. of char:3
# QUA.png no. of char:3
# QUC.png no. of char:3
# QUKM.png no. of char:4
# QUM.png no. of char:3
# QUO.png no. of char:3
# QUZH.png no. of char:4
# QUZU.png no. of char:4
# QVPS.png no. of char:4
# QVV.png no. of char:3
# QWCX.png no. of char:4
# QWQ.png no. of char:3
# QXD.png no. of char:3
# QXQ.png no. of char:3
# QXTF.png no. of char:4
# QXU.png no. of char:3
# QXUJ.png no. of char:4
# QXW.png no. of char:3
# QYHM.png no. of char:4
# QYN.png no. of char:3
# QYQ.png no. of char:3
# QYZQ.png no. of char:4
# QZC.png no. of char:3
# QZLS.png no. of char:4
# QZP.png no. of char:3
# RAD.png no. of char:3
# RBG.png no. of char:3
# RBO.png no. of char:3
# RBR.png no. of char:3
# RBW.png no. of char:3
# RBZ.png no. of char:3
# RCI.png no. of char:3
# RCJ.png no. of char:3
# RCRY.png no. of char:4
# RDLS.png no. of char:4
# RDOT.png no. of char:4
# RDSQ.png no. of char:4
# REED.png no. of char:4
# REN.png no. of char:3
# REP.png no. of char:3
# RES.png no. of char:3
# REV.png no. of char:3
# RFAE.png no. of char:4
# RFL.png no. of char:3
# RGSX.png no. of char:4
# RGW.png no. of char:3
# RHD.png no. of char:3
# RHI.png no. of char:3
# RHS.png no. of char:3
# RHTJ.png no. of char:4
# RJBP.png no. of char:4
# RJBY.png no. of char:4
# RJN.png no. of char:3
# RJX.png no. of char:3
# RLCK.png no. of char:4
# RLF.png no. of char:3
# RLOL.png no. of char:4
# RMC.png no. of char:3
# RME.png no. of char:3
# RMJ.png no. of char:3
# RMS.png no. of char:3
# RMUP.png no. of char:4
# RNLK.png no. of char:4
# RNS.png no. of char:3
# RNUJ.png no. of char:4
# ROC.png no. of char:3
# ROQ.png no. of char:3
# RPAX.png no. of char:4
# RPFB.png no. of char:4
# RPQW.png no. of char:4
# RQD.png no. of char:3
# RQO.png no. of char:3
# RQSL.png no. of char:4
# RRI.png no. of char:3
# RSB.png no. of char:3
# RSC.png no. of char:3
# RSDG.png no. of char:4
# RSKC.png no. of char:4
# RSNL.png no. of char:4
# RSVF.png no. of char:4
# RSX.png no. of char:3
# RTF.png no. of char:3
# RTR.png no. of char:3
# RTYL.png no. of char:4
# RUN.png no. of char:3
# RUQ.png no. of char:3
# RUV.png no. of char:3
# RVB.png no. of char:3
# RVEM.png no. of char:4
# RVQ.png no. of char:3
# RWCP.png no. of char:4
# RWDL.png no. of char:4
# RXLS.png no. of char:4
# RYUA.png no. of char:4
# RYXY.png no. of char:4
# RZBR.png no. of char:4
# RZW.png no. of char:3
# SAE.png no. of char:3
# SAI.png no. of char:3
# SAR.png no. of char:3
# SBJE.png no. of char:4
# SBNC.png no. of char:4
# SBWX.png no. of char:4
# SCHS.png no. of char:4
# SCO.png no. of char:3
# SCX.png no. of char:3
# SCZB.png no. of char:4
# SDB.png no. of char:3
# SDJS.png no. of char:4
# SDNI.png no. of char:4
# SDR.png no. of char:3
# SDTB.png no. of char:4
# SDWF.png no. of char:4
# SDYL.png no. of char:4
# SEYM.png no. of char:4
# SFA.png no. of char:3
# SFI.png no. of char:3
# SFM.png no. of char:3
# SFUC.png no. of char:4
# SGI.png no. of char:3
# SGQR.png no. of char:4
# SGR.png no. of char:3
# SGU.png no. of char:3
# SGW.png no. of char:3
# SHO.png no. of char:3
# SID.png no. of char:3
# SIQJ.png no. of char:4
# SJL.png no. of char:3
# SJSY.png no. of char:4
# SJUC.png no. of char:4
# SJZ.png no. of char:3
# SKGO.png no. of char:4
# SKIK.png no. of char:4
# SKLK.png no. of char:4
# SKNM.png no. of char:4
# SKO.png no. of char:3
# SKZJ.png no. of char:4
# SLXO.png no. of char:4
# SLY.png no. of char:3
# SMC.png no. of char:3
# SML.png no. of char:3
# SMR.png no. of char:3
# SMU.png no. of char:3
# SNI.png no. of char:3
# SNJ.png no. of char:3
# SNJD.png no. of char:4
# SOR.png no. of char:3
# SPRA.png no. of char:4
# SPS.png no. of char:3
# SPV.png no. of char:3
# SPXG.png no. of char:4
# SQEV.png no. of char:4
# SQHR.png no. of char:4
# SQSJ.png no. of char:4
# SQSP.png no. of char:4
# SRA.png no. of char:3
# SRB.png no. of char:3
# SRK.png no. of char:3
# SRM.png no. of char:3
# SRN.png no. of char:3
# SRY.png no. of char:3
# SSB.png no. of char:3
# SSH.png no. of char:3
# SSVB.png no. of char:4
# SSW.png no. of char:3
# SSXN.png no. of char:4
# STBO.png no. of char:4
# STG.png no. of char:3
# STKF.png no. of char:4
# STLC.png no. of char:4
# STO.png no. of char:3
# SUB.png no. of char:3
# SUE.png no. of char:3
# SUQE.png no. of char:4
# SUZ.png no. of char:3
# SVD.png no. of char:3
# SVG.png no. of char:3
# SVOI.png no. of char:4
# SYL.png no. of char:3
# SYLR.png no. of char:4
# SYVZ.png no. of char:4
# SZLC.png no. of char:4
# SZWH.png no. of char:4
# TAAV.png no. of char:4
# TACG.png no. of char:4
# TAMA.png no. of char:4
# TANI.png no. of char:4
# TANW.png no. of char:4
# TBR.png no. of char:3
# TCM.png no. of char:3
# TDBK.png no. of char:4
# TDJ.png no. of char:3
# TDOH.png no. of char:4
# TEDB.png no. of char:4
# TEJ.png no. of char:3
# TEMC.png no. of char:4
# TEU.png no. of char:3
# TFNX.png no. of char:4
# TFP.png no. of char:3
# TFU.png no. of char:3
# TFX.png no. of char:3
# TGF.png no. of char:3
# TGH.png no. of char:3
# TGL.png no. of char:3
# THG.png no. of char:3
# TING.png no. of char:4
# TIQ.png no. of char:3
# TJC.png no. of char:3
# TJO.png no. of char:3
# TJVD.png no. of char:4
# TJYW.png no. of char:4
# TKHG.png no. of char:4
# TKI.png no. of char:3
# TKL.png no. of char:3
# TKX.png no. of char:3
# TLIP.png no. of char:4
# TLM.png no. of char:3
# TMSK.png no. of char:4
# TMZ.png no. of char:3
# TNEC.png no. of char:4
# TNEJ.png no. of char:4
# TNG.png no. of char:3
# TNHX.png no. of char:4
# TNZJ.png no. of char:4
# TOOX.png no. of char:4
# TOZY.png no. of char:4
# TQN.png no. of char:3
# TQR.png no. of char:3
# TRWJ.png no. of char:4
# TRY.png no. of char:3
# TSA.png no. of char:3
# TSNH.png no. of char:4
# TSNL.png no. of char:4
# TSS.png no. of char:3
# TTU.png no. of char:3
# TUAY.png no. of char:4
# TUGG.png no. of char:4
# TUM.png no. of char:3
# TUO.png no. of char:3
# TUP.png no. of char:3
# TUR.png no. of char:3
# TUS.png no. of char:3
# TUW.png no. of char:3
# TUY.png no. of char:3
# TVH.png no. of char:3
# TVI.png no. of char:3
# TVV.png no. of char:3
# TWAM.png no. of char:4
# TWHE.png no. of char:4
# TWJF.png no. of char:4
# TWOJ.png no. of char:4
# TWS.png no. of char:3
# TWU.png no. of char:3
# TWUG.png no. of char:4
# TXED.png no. of char:4
# TXRA.png no. of char:4
# TXV.png no. of char:3
# TYF.png no. of char:3
# TYH.png no. of char:3
# TYTB.png no. of char:4
# TZCW.png no. of char:4
# TZDJ.png no. of char:4
# TZFK.png no. of char:4
# TZP.png no. of char:3
# TZSC.png no. of char:4
# UAMV.png no. of char:4
# UAYN.png no. of char:4
# UBB.png no. of char:3
# UBBA.png no. of char:4
# UBJ.png no. of char:3
# UBKF.png no. of char:4
# UBMM.png no. of char:4
# UBQR.png no. of char:4
# UBS.png no. of char:3
# UCBI.png no. of char:4
# UCS.png no. of char:3
# UDJZ.png no. of char:4
# UFFS.png no. of char:4
# UFL.png no. of char:3
# UFPA.png no. of char:4
# UFZI.png no. of char:4
# UGJ.png no. of char:3
# UGJC.png no. of char:4
# UHG.png no. of char:3
# UHL.png no. of char:3
# UHTF.png no. of char:4
# UIHP.png no. of char:4
# UIJG.png no. of char:4
# UIUV.png no. of char:4
# UIW.png no. of char:3
# UIYS.png no. of char:4
# UKBZ.png no. of char:4
# UKQX.png no. of char:4
# UKR.png no. of char:3
# UKU.png no. of char:3
# ULOH.png no. of char:4
# ULRL.png no. of char:4
# UMFV.png no. of char:4
# UNA.png no. of char:3
# UNP.png no. of char:3
# UNPY.png no. of char:4
# UNSR.png no. of char:4
# UNZO.png no. of char:4
# UOEX.png no. of char:4
# UOJT.png no. of char:4
# UORG.png no. of char:4
# UOTE.png no. of char:4
# UOXX.png no. of char:4
# UOZ.png no. of char:3
# UPFO.png no. of char:4
# UPGV.png no. of char:4
# UPI.png no. of char:3
# UPPI.png no. of char:4
# UPUE.png no. of char:4
# UQC.png no. of char:3
# UQIX.png no. of char:4
# UQN.png no. of char:3
# UQS.png no. of char:3
# UQZ.png no. of char:3
# URW.png no. of char:3
# USB.png no. of char:3
# USW.png no. of char:3
# UTV.png no. of char:3
# UUJ.png no. of char:3
# UUU.png no. of char:3
# UUWY.png no. of char:4
# UUZ.png no. of char:3
# UWJF.png no. of char:4
# UWJO.png no. of char:4
# UXFM.png no. of char:4
# UXLJ.png no. of char:4
# UYMB.png no. of char:4
# UYPK.png no. of char:4
# UYQI.png no. of char:4
# UYT.png no. of char:3
# UZDM.png no. of char:4
# UZS.png no. of char:3
# VAT.png no. of char:3
# VAVS.png no. of char:4
# VAW.png no. of char:3
# VBA.png no. of char:3
# VBBB.png no. of char:4
# VBN.png no. of char:3
# VCC.png no. of char:3
# VCHQ.png no. of char:4
# VCK.png no. of char:3
# VCQ.png no. of char:3
# VCS.png no. of char:3
# VCX.png no. of char:3
# VDFM.png no. of char:4
# VDK.png no. of char:3
# VDP.png no. of char:3
# VDRS.png no. of char:4
# VDV.png no. of char:3
# VEFL.png no. of char:4
# VEXM.png no. of char:4
# VFDO.png no. of char:4
# VFEU.png no. of char:4
# VFHB.png no. of char:4
# VFP.png no. of char:3
# VGG.png no. of char:3
# VGPG.png no. of char:4
# VHDH.png no. of char:4
# VHM.png no. of char:3
# VHOJ.png no. of char:4
# VHTI.png no. of char:4
# VIEK.png no. of char:4
# VINX.png no. of char:4
# VIP.png no. of char:3
# VITV.png no. of char:4
# VJEC.png no. of char:4
# VJPE.png no. of char:4
# VKD.png no. of char:3
# VKN.png no. of char:3
# VKQ.png no. of char:3
# VKQK.png no. of char:4
# VKS.png no. of char:3
# VKUG.png no. of char:4
# VKUU.png no. of char:4
# VKXL.png no. of char:4
# VLF.png no. of char:3
# VLUK.png no. of char:4
# VMC.png no. of char:3
# VMCS.png no. of char:4
# VMOS.png no. of char:4
# VMQ.png no. of char:3
# VMRR.png no. of char:4
# VMT.png no. of char:3
# VMTY.png no. of char:4
# VNM.png no. of char:3
# VNMP.png no. of char:4
# VNT.png no. of char:3
# VNU.png no. of char:3
# VNWU.png no. of char:4
# VOBM.png no. of char:4
# VONC.png no. of char:4
# VPAO.png no. of char:4
# VPEN.png no. of char:4
# VPIW.png no. of char:4
# VSKX.png no. of char:4
# VSN.png no. of char:3
# VSPQ.png no. of char:4
# VSW.png no. of char:3
# VTHD.png no. of char:4
# VTNE.png no. of char:4
# VUDU.png no. of char:4
# VVE.png no. of char:3
# VWBN.png no. of char:4
# VWLU.png no. of char:4
# VWUL.png no. of char:4
# VXNG.png no. of char:4
# VYYQ.png no. of char:4
# VZDX.png no. of char:4
# VZQH.png no. of char:4
# WAZW.png no. of char:4
# WBEA.png no. of char:4
# WBI.png no. of char:3
# WBLN.png no. of char:4
# WBPY.png no. of char:4
# WBS.png no. of char:3
# WBSD.png no. of char:4
# WBT.png no. of char:3
# WCQ.png no. of char:3
# WCQB.png no. of char:4
# WCR.png no. of char:3
# WDE.png no. of char:3
# WDGI.png no. of char:4
# WDOU.png no. of char:4
# WDZ.png no. of char:3
# WEG.png no. of char:3
# WFC.png no. of char:3
# WFD.png no. of char:3
# WFMT.png no. of char:4
# WFS.png no. of char:3
# WFTY.png no. of char:4
# WFW.png no. of char:3
# WGL.png no. of char:3
# WGW.png no. of char:3
# WGXV.png no. of char:4
# WHDQ.png no. of char:4
# WHK.png no. of char:3
# WICO.png no. of char:4
# WIJS.png no. of char:4
# WIJX.png no. of char:4
# WJE.png no. of char:3
# WJK.png no. of char:3
# WJMM.png no. of char:4
# WKE.png no. of char:3
# WKMG.png no. of char:4
# WLAU.png no. of char:4
# WLB.png no. of char:3
# WLYG.png no. of char:4
# WMB.png no. of char:3
# WMR.png no. of char:3
# WNBE.png no. of char:4
# WNW.png no. of char:3
# WOD.png no. of char:3
# WOO.png no. of char:3
# WOP.png no. of char:3
# WOU.png no. of char:3
# WPV.png no. of char:3
# WQGT.png no. of char:4
# WQRE.png no. of char:4
# WQSO.png no. of char:4
# WQSW.png no. of char:4
# WRH.png no. of char:3
# WRI.png no. of char:3
# WRJS.png no. of char:4
# WRN.png no. of char:3
# WRXQ.png no. of char:4
# WRY.png no. of char:3
# WSB.png no. of char:3
# WSSB.png no. of char:4
# WSU.png no. of char:3
# WSV.png no. of char:3
# WSWD.png no. of char:4
# WTJ.png no. of char:3
# WTSP.png no. of char:4
# WTT.png no. of char:3
# WUBV.png no. of char:4
# WUJ.png no. of char:3
# WUMZ.png no. of char:4
# WUSY.png no. of char:4
# WUT.png no. of char:3
# WUW.png no. of char:3
# WUX.png no. of char:3
# WUY.png no. of char:3
# WVH.png no. of char:3
# WVOK.png no. of char:4
# WVZF.png no. of char:4
# WXA.png no. of char:3
# WXC.png no. of char:3
# WYJ.png no. of char:3
# WYM.png no. of char:3
# WYZG.png no. of char:4
# WZHJ.png no. of char:4
# WZS.png no. of char:3
# WZZ.png no. of char:3
# XAC.png no. of char:3
# XAG.png no. of char:3
# XAO.png no. of char:3
# XAOR.png no. of char:4
# XBHU.png no. of char:4
# XBQ.png no. of char:3
# XBYI.png no. of char:4
# XBZ.png no. of char:3
# XCCU.png no. of char:4
# XCDE.png no. of char:4
# XCFW.png no. of char:4
# XCI.png no. of char:3
# XDG.png no. of char:3
# XDM.png no. of char:3
# XDO.png no. of char:3
# XDV.png no. of char:3
# XEEW.png no. of char:4
# XEY.png no. of char:3
# XFH.png no. of char:3
# XFN.png no. of char:3
# XFQL.png no. of char:4
# XFRH.png no. of char:4
# XGLV.png no. of char:4
# XGN.png no. of char:3
# XHC.png no. of char:3
# XHFR.png no. of char:4
# XIOQ.png no. of char:4
# XIVG.png no. of char:4
# XIY.png no. of char:3
# XIZK.png no. of char:4
# XJS.png no. of char:3
# XJTB.png no. of char:4
# XKR.png no. of char:3
# XKU.png no. of char:3
# XLM.png no. of char:3
# XLN.png no. of char:3
# XMMG.png no. of char:4
# XMN.png no. of char:3
# XMV.png no. of char:3
# XNHS.png no. of char:4
# XNV.png no. of char:3
# XOC.png no. of char:3
# XOO.png no. of char:3
# XOR.png no. of char:3
# XOU.png no. of char:3
# XOX.png no. of char:3
# XOZ.png no. of char:3
# XPAH.png no. of char:4
# XPD.png no. of char:3
# XPKU.png no. of char:4
# XPOF.png no. of char:4
# XPTP.png no. of char:4
# XPW.png no. of char:3
# XQDX.png no. of char:4
# XQI.png no. of char:3
# XQIT.png no. of char:4
# XQLO.png no. of char:4
# XQO.png no. of char:3
# XQS.png no. of char:3
# XQW.png no. of char:3
# XQY.png no. of char:3
# XRF.png no. of char:3
# XRKQ.png no. of char:4
# XSHA.png no. of char:4
# XTA.png no. of char:3
# XTCY.png no. of char:4
# XTDM.png no. of char:4
# XTOV.png no. of char:4

# %%
#for filename in os.listdir('train'):
 #   img = cv.imread('train/'+filename,-1)
captacha_image='img3.png'
img = cv.imread(captacha_image,-1)
hsv = cv.cvtColor(img, cv.COLOR_BGR2HSV)
lower_red = np.array([0,0,150])
upper_red = np.array([255,255,255])
filename = os.path.basename(captacha_image)
captcha_text = os.path.splitext(filename)[0]
mask = cv.inRange(hsv, lower_red, upper_red)
imCopy = mask.copy()
imCopy=~imCopy
#res = cv.bitwise_and(img,img,mask=mask)
#blured = cv.blur(gray, (5,5), 0) 
#edged = cv.Canny(mask, 30, 200) 
#cv.waitKey(0) 
contours,hierarchy= cv.findContours(imCopy, cv.RETR_EXTERNAL, cv.CHAIN_APPROX_NONE)[-2:]
letter_image_regions = []
for contour in contours:
  # Get the rectangle that contains the contour
  (x, y, w, h) = cv.boundingRect(contour)
        
  # checking if any counter is too wide
  # if countour is too wide then there could be two letters joined together or are very close to each other
  if h!=0 and w / h > 1.25:
    # Split it in half into two letter regions
    half_width = int(w / 2)
    letter_image_regions.append((x, y, half_width, h))
    letter_image_regions.append((x + half_width, y, half_width, h))
  else:  
    letter_image_regions.append((x, y, w, h))
# cv.drawContours(mask, contours, -1, (255, 255,255), 3)    
# cv.imwrite('ABJG.png',mask)

# %%
letter_image_regions = sorted(letter_image_regions, key=lambda x: x[0])
print(letter_image_regions)

# Save each letter as a single image
for letter_bounding_box, letter_text in zip(letter_image_regions, 'ABJG'):
  # Grab the coordinates of the letter in the image
  x, y, w, h = letter_bounding_box

  # Extract the letter from the original image with a 2-pixel margin around the edge
  letter_image = mask[y - 2:y + h + 2, x - 2:x + w + 2]
# Out:
# [(58, 34, 85, 89), (196, 34, 86, 82), (400, 29, 80, 90)]

# %%
import cv2

SOLVED_CAPTCHA_FOLDER = "train"
OUTPUT_FOLDER = "extracted_letters"


# Get the path of all the solved captcha images
solved_captchas = glob.glob(os.path.join(SOLVED_CAPTCHA_FOLDER, "*"))
counts = {}

# loop over the image paths
for (i, captcha) in enumerate(solved_captchas):
    print("processing image {}/{}".format(i + 1, len(solved_captchas)))

    
    # grab the base filename as the text
    filename = os.path.basename(captcha)
    captcha_text = os.path.splitext(filename)[0]

    img = cv.imread(captcha,-1)
    hsv = cv.cvtColor(img, cv.COLOR_BGR2HSV)
    lower_red = np.array([0,0,150])
    upper_red = np.array([255,255,255])
    # Load the image and convert it to grayscale
#     image = cv2.imread(captcha)
#     gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    mask = cv.inRange(hsv, lower_red, upper_red)
    imCopy = mask.copy()
    imCopy=~imCopy
#     # Add some extra padding around the image
#     gray = cv2.copyMakeBorder(gray, 8, 8, 8, 8, cv2.BORDER_REPLICATE)

#     # applying threshold
#     thresh = cv2.threshold(gray, 127, 255, cv2.THRESH_BINARY_INV, cv2.THRESH_OTSU)[1]
    contours,hierarchy= cv.findContours(imCopy, cv.RETR_EXTERNAL, cv.CHAIN_APPROX_NONE)[-2:]
    letter_image_regions = []
#      # finding the contours
#     contours, hierarchy = cv2.findContours(thresh.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

#     # creating empty list for holding the coordinates of the letters
#     letter_image_regions = []


    # Now we will loop through each of the contours and extract the letter
    for contour in contours:
        # Get the rectangle that contains the contour
        (x, y, w, h) = cv2.boundingRect(contour)
        
        # checking if any counter is too wide
        # if countour is too wide then there could be two letters joined together or are very close to each other
        if h!=0 and w / h > 1.5:
            # Split it in half into two letter regions
            half_width = int(w / 2)
            letter_image_regions.append((x, y, half_width, h))
            letter_image_regions.append((x + half_width, y, half_width, h))
        else:
            
            letter_image_regions.append((x, y, w, h))
            

    
    # Sort the detected letter images based on the x coordinate to make sure
    # we get them from left-to-right so that we match the right image with the right letter
    letter_image_regions = sorted(letter_image_regions, key=lambda x: x[0])
    
    # Save each letter as a single image
    for letter_bounding_box, letter_text in zip(letter_image_regions, captcha_text):
        # Grab the coordinates of the letter in the image
        x, y, w, h = letter_bounding_box

        # Extract the letter from the original image with a 2-pixel margin around the edge
        letter_image = mask[y - 2:y + h + 2, x - 2:x + w + 2]


        # Get the folder to save the image in
        save_path = os.path.join(OUTPUT_FOLDER, letter_text)

        # creating different output folder for storing different letters
        if not os.path.exists(save_path):
            os.makedirs(save_path)

        # write the letter image to a file
        count = counts.get(letter_text, 1)
        p = os.path.join(save_path, "{}.png".format(str(count)))
        cv2.imwrite(p, letter_image)
        #cv2.imshow('image',letter_image)

        # increment the count
        counts[letter_text] = count + 1
# Out:
# processing image 1/2000
# processing image 2/2000
# processing image 3/2000
# processing image 4/2000
# processing image 5/2000
# processing image 6/2000
# processing image 7/2000
# processing image 8/2000
# processing image 9/2000
# processing image 10/2000
# processing image 11/2000
# processing image 12/2000
# processing image 13/2000
# processing image 14/2000
# processing image 15/2000
# processing image 16/2000
# processing image 17/2000
# processing image 18/2000
# processing image 19/2000
# processing image 20/2000
# processing image 21/2000
# processing image 22/2000
# processing image 23/2000
# processing image 24/2000
# processing image 25/2000
# processing image 26/2000
# processing image 27/2000
# processing image 28/2000
# processing image 29/2000
# processing image 30/2000
# processing image 31/2000
# processing image 32/2000
# processing image 33/2000
# processing image 34/2000
# processing image 35/2000
# processing image 36/2000
# processing image 37/2000
# processing image 38/2000
# processing image 39/2000
# processing image 40/2000
# processing image 41/2000
# processing image 42/2000
# processing image 43/2000
# processing image 44/2000
# processing image 45/2000
# processing image 46/2000
# processing image 47/2000
# processing image 48/2000
# processing image 49/2000
# processing image 50/2000
# processing image 51/2000
# processing image 52/2000
# processing image 53/2000
# processing image 54/2000
# processing image 55/2000
# processing image 56/2000
# processing image 57/2000
# processing image 58/2000
# processing image 59/2000
# processing image 60/2000
# processing image 61/2000
# processing image 62/2000
# processing image 63/2000
# processing image 64/2000
# processing image 65/2000
# processing image 66/2000
# processing image 67/2000
# processing image 68/2000
# processing image 69/2000
# processing image 70/2000
# processing image 71/2000
# processing image 72/2000
# processing image 73/2000
# processing image 74/2000
# processing image 75/2000
# processing image 76/2000
# processing image 77/2000
# processing image 78/2000
# processing image 79/2000
# processing image 80/2000
# processing image 81/2000
# processing image 82/2000
# processing image 83/2000
# processing image 84/2000
# processing image 85/2000
# processing image 86/2000
# processing image 87/2000
# processing image 88/2000
# processing image 89/2000
# processing image 90/2000
# processing image 91/2000
# processing image 92/2000
# processing image 93/2000
# processing image 94/2000
# processing image 95/2000
# processing image 96/2000
# processing image 97/2000
# processing image 98/2000
# processing image 99/2000
# processing image 100/2000
# processing image 101/2000
# processing image 102/2000
# processing image 103/2000
# processing image 104/2000
# processing image 105/2000
# processing image 106/2000
# processing image 107/2000
# processing image 108/2000
# processing image 109/2000
# processing image 110/2000
# processing image 111/2000
# processing image 112/2000
# processing image 113/2000
# processing image 114/2000
# processing image 115/2000
# processing image 116/2000
# processing image 117/2000
# processing image 118/2000
# processing image 119/2000
# processing image 120/2000
# processing image 121/2000
# processing image 122/2000
# processing image 123/2000
# processing image 124/2000
# processing image 125/2000
# processing image 126/2000
# processing image 127/2000
# processing image 128/2000
# processing image 129/2000
# processing image 130/2000
# processing image 131/2000
# processing image 132/2000
# processing image 133/2000
# processing image 134/2000
# processing image 135/2000
# processing image 136/2000
# processing image 137/2000
# processing image 138/2000
# processing image 139/2000
# processing image 140/2000
# processing image 141/2000
# processing image 142/2000
# processing image 143/2000
# processing image 144/2000
# processing image 145/2000
# processing image 146/2000
# processing image 147/2000
# processing image 148/2000
# processing image 149/2000
# processing image 150/2000
# processing image 151/2000
# processing image 152/2000
# processing image 153/2000
# processing image 154/2000
# processing image 155/2000
# processing image 156/2000
# processing image 157/2000
# processing image 158/2000
# processing image 159/2000
# processing image 160/2000
# processing image 161/2000
# processing image 162/2000
# processing image 163/2000
# processing image 164/2000
# processing image 165/2000
# processing image 166/2000
# processing image 167/2000
# processing image 168/2000
# processing image 169/2000
# processing image 170/2000
# processing image 171/2000
# processing image 172/2000
# processing image 173/2000
# processing image 174/2000
# processing image 175/2000
# processing image 176/2000
# processing image 177/2000
# processing image 178/2000
# processing image 179/2000
# processing image 180/2000
# processing image 181/2000
# processing image 182/2000
# processing image 183/2000
# processing image 184/2000
# processing image 185/2000
# processing image 186/2000
# processing image 187/2000
# processing image 188/2000
# processing image 189/2000
# processing image 190/2000
# processing image 191/2000
# processing image 192/2000
# processing image 193/2000
# processing image 194/2000
# processing image 195/2000
# processing image 196/2000
# processing image 197/2000
# processing image 198/2000
# processing image 199/2000
# processing image 200/2000
# processing image 201/2000
# processing image 202/2000
# processing image 203/2000
# processing image 204/2000
# processing image 205/2000
# processing image 206/2000
# processing image 207/2000
# processing image 208/2000
# processing image 209/2000
# processing image 210/2000
# processing image 211/2000
# processing image 212/2000
# processing image 213/2000
# processing image 214/2000
# processing image 215/2000
# processing image 216/2000
# processing image 217/2000
# processing image 218/2000
# processing image 219/2000
# processing image 220/2000
# processing image 221/2000
# processing image 222/2000
# processing image 223/2000
# processing image 224/2000
# processing image 225/2000
# processing image 226/2000
# processing image 227/2000
# processing image 228/2000
# processing image 229/2000
# processing image 230/2000
# processing image 231/2000
# processing image 232/2000
# processing image 233/2000
# processing image 234/2000
# processing image 235/2000
# processing image 236/2000
# processing image 237/2000
# processing image 238/2000
# processing image 239/2000
# processing image 240/2000
# processing image 241/2000
# processing image 242/2000
# processing image 243/2000
# processing image 244/2000
# processing image 245/2000
# processing image 246/2000
# processing image 247/2000
# processing image 248/2000
# processing image 249/2000
# processing image 250/2000
# processing image 251/2000
# processing image 252/2000
# processing image 253/2000
# processing image 254/2000
# processing image 255/2000
# processing image 256/2000
# processing image 257/2000
# processing image 258/2000
# processing image 259/2000
# processing image 260/2000
# processing image 261/2000
# processing image 262/2000
# processing image 263/2000
# processing image 264/2000
# processing image 265/2000
# processing image 266/2000
# processing image 267/2000
# processing image 268/2000
# processing image 269/2000
# processing image 270/2000
# processing image 271/2000
# processing image 272/2000
# processing image 273/2000
# processing image 274/2000
# processing image 275/2000
# processing image 276/2000
# processing image 277/2000
# processing image 278/2000
# processing image 279/2000
# processing image 280/2000
# processing image 281/2000
# processing image 282/2000
# processing image 283/2000
# processing image 284/2000
# processing image 285/2000
# processing image 286/2000
# processing image 287/2000
# processing image 288/2000
# processing image 289/2000
# processing image 290/2000
# processing image 291/2000
# processing image 292/2000
# processing image 293/2000
# processing image 294/2000
# processing image 295/2000
# processing image 296/2000
# processing image 297/2000
# processing image 298/2000
# processing image 299/2000
# processing image 300/2000
# processing image 301/2000
# processing image 302/2000
# processing image 303/2000
# processing image 304/2000
# processing image 305/2000
# processing image 306/2000
# processing image 307/2000
# processing image 308/2000
# processing image 309/2000
# processing image 310/2000
# processing image 311/2000
# processing image 312/2000
# processing image 313/2000
# processing image 314/2000
# processing image 315/2000
# processing image 316/2000
# processing image 317/2000
# processing image 318/2000
# processing image 319/2000
# processing image 320/2000
# processing image 321/2000
# processing image 322/2000
# processing image 323/2000
# processing image 324/2000
# processing image 325/2000
# processing image 326/2000
# processing image 327/2000
# processing image 328/2000
# processing image 329/2000
# processing image 330/2000
# processing image 331/2000
# processing image 332/2000
# processing image 333/2000
# processing image 334/2000
# processing image 335/2000
# processing image 336/2000
# processing image 337/2000
# processing image 338/2000
# processing image 339/2000
# processing image 340/2000
# processing image 341/2000
# processing image 342/2000
# processing image 343/2000
# processing image 344/2000
# processing image 345/2000
# processing image 346/2000
# processing image 347/2000
# processing image 348/2000
# processing image 349/2000
# processing image 350/2000
# processing image 351/2000
# processing image 352/2000
# processing image 353/2000
# processing image 354/2000
# processing image 355/2000
# processing image 356/2000
# processing image 357/2000
# processing image 358/2000
# processing image 359/2000
# processing image 360/2000
# processing image 361/2000
# processing image 362/2000
# processing image 363/2000
# processing image 364/2000
# processing image 365/2000
# processing image 366/2000
# processing image 367/2000
# processing image 368/2000
# processing image 369/2000
# processing image 370/2000
# processing image 371/2000
# processing image 372/2000
# processing image 373/2000
# processing image 374/2000
# processing image 375/2000
# processing image 376/2000
# processing image 377/2000
# processing image 378/2000
# processing image 379/2000
# processing image 380/2000
# processing image 381/2000
# processing image 382/2000
# processing image 383/2000
# processing image 384/2000
# processing image 385/2000
# processing image 386/2000
# processing image 387/2000
# processing image 388/2000
# processing image 389/2000
# processing image 390/2000
# processing image 391/2000
# processing image 392/2000
# processing image 393/2000
# processing image 394/2000
# processing image 395/2000
# processing image 396/2000
# processing image 397/2000
# processing image 398/2000
# processing image 399/2000
# processing image 400/2000
# processing image 401/2000
# processing image 402/2000
# processing image 403/2000
# processing image 404/2000
# processing image 405/2000
# processing image 406/2000
# processing image 407/2000
# processing image 408/2000
# processing image 409/2000
# processing image 410/2000
# processing image 411/2000
# processing image 412/2000
# processing image 413/2000
# processing image 414/2000
# processing image 415/2000
# processing image 416/2000
# processing image 417/2000
# processing image 418/2000
# processing image 419/2000
# processing image 420/2000
# processing image 421/2000
# processing image 422/2000
# processing image 423/2000
# processing image 424/2000
# processing image 425/2000
# processing image 426/2000
# processing image 427/2000
# processing image 428/2000
# processing image 429/2000
# processing image 430/2000
# processing image 431/2000
# processing image 432/2000
# processing image 433/2000
# processing image 434/2000
# processing image 435/2000
# processing image 436/2000
# processing image 437/2000
# processing image 438/2000
# processing image 439/2000
# processing image 440/2000
# processing image 441/2000
# processing image 442/2000
# processing image 443/2000
# processing image 444/2000
# processing image 445/2000
# processing image 446/2000
# processing image 447/2000
# processing image 448/2000
# processing image 449/2000
# processing image 450/2000
# processing image 451/2000
# processing image 452/2000
# processing image 453/2000
# processing image 454/2000
# processing image 455/2000
# processing image 456/2000
# processing image 457/2000
# processing image 458/2000
# processing image 459/2000
# processing image 460/2000
# processing image 461/2000
# processing image 462/2000
# processing image 463/2000
# processing image 464/2000
# processing image 465/2000
# processing image 466/2000
# processing image 467/2000
# processing image 468/2000
# processing image 469/2000
# processing image 470/2000
# processing image 471/2000
# processing image 472/2000
# processing image 473/2000
# processing image 474/2000
# processing image 475/2000
# processing image 476/2000
# processing image 477/2000
# processing image 478/2000
# processing image 479/2000
# processing image 480/2000
# processing image 481/2000
# processing image 482/2000
# processing image 483/2000
# processing image 484/2000
# processing image 485/2000
# processing image 486/2000
# processing image 487/2000
# processing image 488/2000
# processing image 489/2000
# processing image 490/2000
# processing image 491/2000
# processing image 492/2000
# processing image 493/2000
# processing image 494/2000
# processing image 495/2000
# processing image 496/2000
# processing image 497/2000
# processing image 498/2000
# processing image 499/2000
# processing image 500/2000
# processing image 501/2000
# processing image 502/2000
# processing image 503/2000
# processing image 504/2000
# processing image 505/2000
# processing image 506/2000
# processing image 507/2000
# processing image 508/2000
# processing image 509/2000
# processing image 510/2000
# processing image 511/2000
# processing image 512/2000
# processing image 513/2000
# processing image 514/2000
# processing image 515/2000
# processing image 516/2000
# processing image 517/2000
# processing image 518/2000
# processing image 519/2000
# processing image 520/2000
# processing image 521/2000
# processing image 522/2000
# processing image 523/2000
# processing image 524/2000
# processing image 525/2000
# processing image 526/2000
# processing image 527/2000
# processing image 528/2000
# processing image 529/2000
# processing image 530/2000
# processing image 531/2000
# processing image 532/2000
# processing image 533/2000
# processing image 534/2000
# processing image 535/2000
# processing image 536/2000
# processing image 537/2000
# processing image 538/2000
# processing image 539/2000
# processing image 540/2000
# processing image 541/2000
# processing image 542/2000
# processing image 543/2000
# processing image 544/2000
# processing image 545/2000
# processing image 546/2000
# processing image 547/2000
# processing image 548/2000
# processing image 549/2000
# processing image 550/2000
# processing image 551/2000
# processing image 552/2000
# processing image 553/2000
# processing image 554/2000
# processing image 555/2000
# processing image 556/2000
# processing image 557/2000
# processing image 558/2000
# processing image 559/2000
# processing image 560/2000
# processing image 561/2000
# processing image 562/2000
# processing image 563/2000
# processing image 564/2000
# processing image 565/2000
# processing image 566/2000
# processing image 567/2000
# processing image 568/2000
# processing image 569/2000
# processing image 570/2000
# processing image 571/2000
# processing image 572/2000
# processing image 573/2000
# processing image 574/2000
# processing image 575/2000
# processing image 576/2000
# processing image 577/2000
# processing image 578/2000
# processing image 579/2000
# processing image 580/2000
# processing image 581/2000
# processing image 582/2000
# processing image 583/2000
# processing image 584/2000
# processing image 585/2000
# processing image 586/2000
# processing image 587/2000
# processing image 588/2000
# processing image 589/2000
# processing image 590/2000
# processing image 591/2000
# processing image 592/2000
# processing image 593/2000
# processing image 594/2000
# processing image 595/2000
# processing image 596/2000
# processing image 597/2000
# processing image 598/2000
# processing image 599/2000
# processing image 600/2000
# processing image 601/2000
# processing image 602/2000
# processing image 603/2000
# processing image 604/2000
# processing image 605/2000
# processing image 606/2000
# processing image 607/2000
# processing image 608/2000
# processing image 609/2000
# processing image 610/2000
# processing image 611/2000
# processing image 612/2000
# processing image 613/2000
# processing image 614/2000
# processing image 615/2000
# processing image 616/2000
# processing image 617/2000
# processing image 618/2000
# processing image 619/2000
# processing image 620/2000
# processing image 621/2000
# processing image 622/2000
# processing image 623/2000
# processing image 624/2000
# processing image 625/2000
# processing image 626/2000
# processing image 627/2000
# processing image 628/2000
# processing image 629/2000
# processing image 630/2000
# processing image 631/2000
# processing image 632/2000
# processing image 633/2000
# processing image 634/2000
# processing image 635/2000
# processing image 636/2000
# processing image 637/2000
# processing image 638/2000
# processing image 639/2000
# processing image 640/2000
# processing image 641/2000
# processing image 642/2000
# processing image 643/2000
# processing image 644/2000
# processing image 645/2000
# processing image 646/2000
# processing image 647/2000
# processing image 648/2000
# processing image 649/2000
# processing image 650/2000
# processing image 651/2000
# processing image 652/2000
# processing image 653/2000
# processing image 654/2000
# processing image 655/2000
# processing image 656/2000
# processing image 657/2000
# processing image 658/2000
# processing image 659/2000
# processing image 660/2000
# processing image 661/2000
# processing image 662/2000
# processing image 663/2000
# processing image 664/2000
# processing image 665/2000
# processing image 666/2000
# processing image 667/2000
# processing image 668/2000
# processing image 669/2000
# processing image 670/2000
# processing image 671/2000
# processing image 672/2000
# processing image 673/2000
# processing image 674/2000
# processing image 675/2000
# processing image 676/2000
# processing image 677/2000
# processing image 678/2000
# processing image 679/2000
# processing image 680/2000
# processing image 681/2000
# processing image 682/2000
# processing image 683/2000
# processing image 684/2000
# processing image 685/2000
# processing image 686/2000
# processing image 687/2000
# processing image 688/2000
# processing image 689/2000
# processing image 690/2000
# processing image 691/2000
# processing image 692/2000
# processing image 693/2000
# processing image 694/2000
# processing image 695/2000
# processing image 696/2000
# processing image 697/2000
# processing image 698/2000
# processing image 699/2000
# processing image 700/2000
# processing image 701/2000
# processing image 702/2000
# processing image 703/2000
# processing image 704/2000
# processing image 705/2000
# processing image 706/2000
# processing image 707/2000
# processing image 708/2000
# processing image 709/2000
# processing image 710/2000
# processing image 711/2000
# processing image 712/2000
# processing image 713/2000
# processing image 714/2000
# processing image 715/2000
# processing image 716/2000
# processing image 717/2000
# processing image 718/2000
# processing image 719/2000
# processing image 720/2000
# processing image 721/2000
# processing image 722/2000
# processing image 723/2000
# processing image 724/2000
# processing image 725/2000
# processing image 726/2000
# processing image 727/2000
# processing image 728/2000
# processing image 729/2000
# processing image 730/2000
# processing image 731/2000
# processing image 732/2000
# processing image 733/2000
# processing image 734/2000
# processing image 735/2000
# processing image 736/2000
# processing image 737/2000
# processing image 738/2000
# processing image 739/2000
# processing image 740/2000
# processing image 741/2000
# processing image 742/2000
# processing image 743/2000
# processing image 744/2000
# processing image 745/2000
# processing image 746/2000
# processing image 747/2000
# processing image 748/2000
# processing image 749/2000
# processing image 750/2000
# processing image 751/2000
# processing image 752/2000
# processing image 753/2000
# processing image 754/2000
# processing image 755/2000
# processing image 756/2000
# processing image 757/2000
# processing image 758/2000
# processing image 759/2000
# processing image 760/2000
# processing image 761/2000
# processing image 762/2000
# processing image 763/2000
# processing image 764/2000
# processing image 765/2000
# processing image 766/2000
# processing image 767/2000
# processing image 768/2000
# processing image 769/2000
# processing image 770/2000
# processing image 771/2000
# processing image 772/2000
# processing image 773/2000
# processing image 774/2000
# processing image 775/2000
# processing image 776/2000
# processing image 777/2000
# processing image 778/2000
# processing image 779/2000
# processing image 780/2000
# processing image 781/2000
# processing image 782/2000
# processing image 783/2000
# processing image 784/2000
# processing image 785/2000
# processing image 786/2000
# processing image 787/2000
# processing image 788/2000
# processing image 789/2000
# processing image 790/2000
# processing image 791/2000
# processing image 792/2000
# processing image 793/2000
# processing image 794/2000
# processing image 795/2000
# processing image 796/2000
# processing image 797/2000
# processing image 798/2000
# processing image 799/2000
# processing image 800/2000
# processing image 801/2000
# processing image 802/2000
# processing image 803/2000
# processing image 804/2000
# processing image 805/2000
# processing image 806/2000
# processing image 807/2000
# processing image 808/2000
# processing image 809/2000
# processing image 810/2000
# processing image 811/2000
# processing image 812/2000
# processing image 813/2000
# processing image 814/2000
# processing image 815/2000
# processing image 816/2000
# processing image 817/2000
# processing image 818/2000
# processing image 819/2000
# processing image 820/2000
# processing image 821/2000
# processing image 822/2000
# processing image 823/2000
# processing image 824/2000
# processing image 825/2000
# processing image 826/2000
# processing image 827/2000
# processing image 828/2000
# processing image 829/2000
# processing image 830/2000
# processing image 831/2000
# processing image 832/2000
# processing image 833/2000
# processing image 834/2000
# processing image 835/2000
# processing image 836/2000
# processing image 837/2000
# processing image 838/2000
# processing image 839/2000
# processing image 840/2000
# processing image 841/2000
# processing image 842/2000
# processing image 843/2000
# processing image 844/2000
# processing image 845/2000
# processing image 846/2000
# processing image 847/2000
# processing image 848/2000
# processing image 849/2000
# processing image 850/2000
# processing image 851/2000
# processing image 852/2000
# processing image 853/2000
# processing image 854/2000
# processing image 855/2000
# processing image 856/2000
# processing image 857/2000
# processing image 858/2000
# processing image 859/2000
# processing image 860/2000
# processing image 861/2000
# processing image 862/2000
# processing image 863/2000
# processing image 864/2000
# processing image 865/2000
# processing image 866/2000
# processing image 867/2000
# processing image 868/2000
# processing image 869/2000
# processing image 870/2000
# processing image 871/2000
# processing image 872/2000
# processing image 873/2000
# processing image 874/2000
# processing image 875/2000
# processing image 876/2000
# processing image 877/2000
# processing image 878/2000
# processing image 879/2000
# processing image 880/2000
# processing image 881/2000
# processing image 882/2000
# processing image 883/2000
# processing image 884/2000
# processing image 885/2000
# processing image 886/2000
# processing image 887/2000
# processing image 888/2000
# processing image 889/2000
# processing image 890/2000
# processing image 891/2000
# processing image 892/2000
# processing image 893/2000
# processing image 894/2000
# processing image 895/2000
# processing image 896/2000
# processing image 897/2000
# processing image 898/2000
# processing image 899/2000
# processing image 900/2000
# processing image 901/2000
# processing image 902/2000
# processing image 903/2000
# processing image 904/2000
# processing image 905/2000
# processing image 906/2000
# processing image 907/2000
# processing image 908/2000
# processing image 909/2000
# processing image 910/2000
# processing image 911/2000
# processing image 912/2000
# processing image 913/2000
# processing image 914/2000
# processing image 915/2000
# processing image 916/2000
# processing image 917/2000
# processing image 918/2000
# processing image 919/2000
# processing image 920/2000
# processing image 921/2000
# processing image 922/2000
# processing image 923/2000
# processing image 924/2000
# processing image 925/2000
# processing image 926/2000
# processing image 927/2000
# processing image 928/2000
# processing image 929/2000
# processing image 930/2000
# processing image 931/2000
# processing image 932/2000
# processing image 933/2000
# processing image 934/2000
# processing image 935/2000
# processing image 936/2000
# processing image 937/2000
# processing image 938/2000
# processing image 939/2000
# processing image 940/2000
# processing image 941/2000
# processing image 942/2000
# processing image 943/2000
# processing image 944/2000
# processing image 945/2000
# processing image 946/2000
# processing image 947/2000
# processing image 948/2000
# processing image 949/2000
# processing image 950/2000
# processing image 951/2000
# processing image 952/2000
# processing image 953/2000
# processing image 954/2000
# processing image 955/2000
# processing image 956/2000
# processing image 957/2000
# processing image 958/2000
# processing image 959/2000
# processing image 960/2000
# processing image 961/2000
# processing image 962/2000
# processing image 963/2000
# processing image 964/2000
# processing image 965/2000
# processing image 966/2000
# processing image 967/2000
# processing image 968/2000
# processing image 969/2000
# processing image 970/2000
# processing image 971/2000
# processing image 972/2000
# processing image 973/2000
# processing image 974/2000
# processing image 975/2000
# processing image 976/2000
# processing image 977/2000
# processing image 978/2000
# processing image 979/2000
# processing image 980/2000
# processing image 981/2000
# processing image 982/2000
# processing image 983/2000
# processing image 984/2000
# processing image 985/2000
# processing image 986/2000
# processing image 987/2000
# processing image 988/2000
# processing image 989/2000
# processing image 990/2000
# processing image 991/2000
# processing image 992/2000
# processing image 993/2000
# processing image 994/2000
# processing image 995/2000
# processing image 996/2000
# processing image 997/2000
# processing image 998/2000
# processing image 999/2000
# processing image 1000/2000
# processing image 1001/2000
# processing image 1002/2000
# processing image 1003/2000
# processing image 1004/2000
# processing image 1005/2000
# processing image 1006/2000
# processing image 1007/2000
# processing image 1008/2000
# processing image 1009/2000
# processing image 1010/2000
# processing image 1011/2000
# processing image 1012/2000
# processing image 1013/2000
# processing image 1014/2000
# processing image 1015/2000
# processing image 1016/2000
# processing image 1017/2000
# processing image 1018/2000
# processing image 1019/2000
# processing image 1020/2000
# processing image 1021/2000
# processing image 1022/2000
# processing image 1023/2000
# processing image 1024/2000
# processing image 1025/2000
# processing image 1026/2000
# processing image 1027/2000
# processing image 1028/2000
# processing image 1029/2000
# processing image 1030/2000
# processing image 1031/2000
# processing image 1032/2000
# processing image 1033/2000
# processing image 1034/2000
# processing image 1035/2000
# processing image 1036/2000
# processing image 1037/2000
# processing image 1038/2000
# processing image 1039/2000
# processing image 1040/2000
# processing image 1041/2000
# processing image 1042/2000
# processing image 1043/2000
# processing image 1044/2000
# processing image 1045/2000
# processing image 1046/2000
# processing image 1047/2000
# processing image 1048/2000
# processing image 1049/2000
# processing image 1050/2000
# processing image 1051/2000
# processing image 1052/2000
# processing image 1053/2000
# processing image 1054/2000
# processing image 1055/2000
# processing image 1056/2000
# processing image 1057/2000
# processing image 1058/2000
# processing image 1059/2000
# processing image 1060/2000
# processing image 1061/2000
# processing image 1062/2000
# processing image 1063/2000
# processing image 1064/2000
# processing image 1065/2000
# processing image 1066/2000
# processing image 1067/2000
# processing image 1068/2000
# processing image 1069/2000
# processing image 1070/2000
# processing image 1071/2000
# processing image 1072/2000
# processing image 1073/2000
# processing image 1074/2000
# processing image 1075/2000
# processing image 1076/2000
# processing image 1077/2000
# processing image 1078/2000
# processing image 1079/2000
# processing image 1080/2000
# processing image 1081/2000
# processing image 1082/2000
# processing image 1083/2000
# processing image 1084/2000
# processing image 1085/2000
# processing image 1086/2000
# processing image 1087/2000
# processing image 1088/2000
# processing image 1089/2000
# processing image 1090/2000
# processing image 1091/2000
# processing image 1092/2000
# processing image 1093/2000
# processing image 1094/2000
# processing image 1095/2000
# processing image 1096/2000
# processing image 1097/2000
# processing image 1098/2000
# processing image 1099/2000
# processing image 1100/2000
# processing image 1101/2000
# processing image 1102/2000
# processing image 1103/2000
# processing image 1104/2000
# processing image 1105/2000
# processing image 1106/2000
# processing image 1107/2000
# processing image 1108/2000
# processing image 1109/2000
# processing image 1110/2000
# processing image 1111/2000
# processing image 1112/2000
# processing image 1113/2000
# processing image 1114/2000
# processing image 1115/2000
# processing image 1116/2000
# processing image 1117/2000
# processing image 1118/2000
# processing image 1119/2000
# processing image 1120/2000
# processing image 1121/2000
# processing image 1122/2000
# processing image 1123/2000
# processing image 1124/2000
# processing image 1125/2000
# processing image 1126/2000
# processing image 1127/2000
# processing image 1128/2000
# processing image 1129/2000
# processing image 1130/2000
# processing image 1131/2000
# processing image 1132/2000
# processing image 1133/2000
# processing image 1134/2000
# processing image 1135/2000
# processing image 1136/2000
# processing image 1137/2000
# processing image 1138/2000
# processing image 1139/2000
# processing image 1140/2000
# processing image 1141/2000
# processing image 1142/2000
# processing image 1143/2000
# processing image 1144/2000
# processing image 1145/2000
# processing image 1146/2000
# processing image 1147/2000
# processing image 1148/2000
# processing image 1149/2000
# processing image 1150/2000
# processing image 1151/2000
# processing image 1152/2000
# processing image 1153/2000
# processing image 1154/2000
# processing image 1155/2000
# processing image 1156/2000
# processing image 1157/2000
# processing image 1158/2000
# processing image 1159/2000
# processing image 1160/2000
# processing image 1161/2000
# processing image 1162/2000
# processing image 1163/2000
# processing image 1164/2000
# processing image 1165/2000
# processing image 1166/2000
# processing image 1167/2000
# processing image 1168/2000
# processing image 1169/2000
# processing image 1170/2000
# processing image 1171/2000
# processing image 1172/2000
# processing image 1173/2000
# processing image 1174/2000
# processing image 1175/2000
# processing image 1176/2000
# processing image 1177/2000
# processing image 1178/2000
# processing image 1179/2000
# processing image 1180/2000
# processing image 1181/2000
# processing image 1182/2000
# processing image 1183/2000
# processing image 1184/2000
# processing image 1185/2000
# processing image 1186/2000
# processing image 1187/2000
# processing image 1188/2000
# processing image 1189/2000
# processing image 1190/2000
# processing image 1191/2000
# processing image 1192/2000
# processing image 1193/2000
# processing image 1194/2000
# processing image 1195/2000
# processing image 1196/2000
# processing image 1197/2000
# processing image 1198/2000
# processing image 1199/2000
# processing image 1200/2000
# processing image 1201/2000
# processing image 1202/2000
# processing image 1203/2000
# processing image 1204/2000
# processing image 1205/2000
# processing image 1206/2000
# processing image 1207/2000
# processing image 1208/2000
# processing image 1209/2000
# processing image 1210/2000
# processing image 1211/2000
# processing image 1212/2000
# processing image 1213/2000
# processing image 1214/2000
# processing image 1215/2000
# processing image 1216/2000
# processing image 1217/2000
# processing image 1218/2000
# processing image 1219/2000
# processing image 1220/2000
# processing image 1221/2000
# processing image 1222/2000
# processing image 1223/2000
# processing image 1224/2000
# processing image 1225/2000
# processing image 1226/2000
# processing image 1227/2000
# processing image 1228/2000
# processing image 1229/2000
# processing image 1230/2000
# processing image 1231/2000
# processing image 1232/2000
# processing image 1233/2000
# processing image 1234/2000
# processing image 1235/2000
# processing image 1236/2000
# processing image 1237/2000
# processing image 1238/2000
# processing image 1239/2000
# processing image 1240/2000
# processing image 1241/2000
# processing image 1242/2000
# processing image 1243/2000
# processing image 1244/2000
# processing image 1245/2000
# processing image 1246/2000
# processing image 1247/2000
# processing image 1248/2000
# processing image 1249/2000
# processing image 1250/2000
# processing image 1251/2000
# processing image 1252/2000
# processing image 1253/2000
# processing image 1254/2000
# processing image 1255/2000
# processing image 1256/2000
# processing image 1257/2000
# processing image 1258/2000
# processing image 1259/2000
# processing image 1260/2000
# processing image 1261/2000
# processing image 1262/2000
# processing image 1263/2000
# processing image 1264/2000
# processing image 1265/2000
# processing image 1266/2000
# processing image 1267/2000
# processing image 1268/2000
# processing image 1269/2000
# processing image 1270/2000
# processing image 1271/2000
# processing image 1272/2000
# processing image 1273/2000
# processing image 1274/2000
# processing image 1275/2000
# processing image 1276/2000
# processing image 1277/2000
# processing image 1278/2000
# processing image 1279/2000
# processing image 1280/2000
# processing image 1281/2000
# processing image 1282/2000
# processing image 1283/2000
# processing image 1284/2000
# processing image 1285/2000
# processing image 1286/2000
# processing image 1287/2000
# processing image 1288/2000
# processing image 1289/2000
# processing image 1290/2000
# processing image 1291/2000
# processing image 1292/2000
# processing image 1293/2000
# processing image 1294/2000
# processing image 1295/2000
# processing image 1296/2000
# processing image 1297/2000
# processing image 1298/2000
# processing image 1299/2000
# processing image 1300/2000
# processing image 1301/2000
# processing image 1302/2000
# processing image 1303/2000
# processing image 1304/2000
# processing image 1305/2000
# processing image 1306/2000
# processing image 1307/2000
# processing image 1308/2000
# processing image 1309/2000
# processing image 1310/2000
# processing image 1311/2000
# processing image 1312/2000
# processing image 1313/2000
# processing image 1314/2000
# processing image 1315/2000
# processing image 1316/2000
# processing image 1317/2000
# processing image 1318/2000
# processing image 1319/2000
# processing image 1320/2000
# processing image 1321/2000
# processing image 1322/2000
# processing image 1323/2000
# processing image 1324/2000
# processing image 1325/2000
# processing image 1326/2000
# processing image 1327/2000
# processing image 1328/2000
# processing image 1329/2000
# processing image 1330/2000
# processing image 1331/2000
# processing image 1332/2000
# processing image 1333/2000
# processing image 1334/2000
# processing image 1335/2000
# processing image 1336/2000
# processing image 1337/2000
# processing image 1338/2000
# processing image 1339/2000
# processing image 1340/2000
# processing image 1341/2000
# processing image 1342/2000
# processing image 1343/2000
# processing image 1344/2000
# processing image 1345/2000
# processing image 1346/2000
# processing image 1347/2000
# processing image 1348/2000
# processing image 1349/2000
# processing image 1350/2000
# processing image 1351/2000
# processing image 1352/2000
# processing image 1353/2000
# processing image 1354/2000
# processing image 1355/2000
# processing image 1356/2000
# processing image 1357/2000
# processing image 1358/2000
# processing image 1359/2000
# processing image 1360/2000
# processing image 1361/2000
# processing image 1362/2000
# processing image 1363/2000
# processing image 1364/2000
# processing image 1365/2000
# processing image 1366/2000
# processing image 1367/2000
# processing image 1368/2000
# processing image 1369/2000
# processing image 1370/2000
# processing image 1371/2000
# processing image 1372/2000
# processing image 1373/2000
# processing image 1374/2000
# processing image 1375/2000
# processing image 1376/2000
# processing image 1377/2000
# processing image 1378/2000
# processing image 1379/2000
# processing image 1380/2000
# processing image 1381/2000
# processing image 1382/2000
# processing image 1383/2000
# processing image 1384/2000
# processing image 1385/2000
# processing image 1386/2000
# processing image 1387/2000
# processing image 1388/2000
# processing image 1389/2000
# processing image 1390/2000
# processing image 1391/2000
# processing image 1392/2000
# processing image 1393/2000
# processing image 1394/2000
# processing image 1395/2000
# processing image 1396/2000
# processing image 1397/2000
# processing image 1398/2000
# processing image 1399/2000
# processing image 1400/2000
# processing image 1401/2000
# processing image 1402/2000
# processing image 1403/2000
# processing image 1404/2000
# processing image 1405/2000
# processing image 1406/2000
# processing image 1407/2000
# processing image 1408/2000
# processing image 1409/2000
# processing image 1410/2000
# processing image 1411/2000
# processing image 1412/2000
# processing image 1413/2000
# processing image 1414/2000
# processing image 1415/2000
# processing image 1416/2000
# processing image 1417/2000
# processing image 1418/2000
# processing image 1419/2000
# processing image 1420/2000
# processing image 1421/2000
# processing image 1422/2000
# processing image 1423/2000
# processing image 1424/2000
# processing image 1425/2000
# processing image 1426/2000
# processing image 1427/2000
# processing image 1428/2000
# processing image 1429/2000
# processing image 1430/2000
# processing image 1431/2000
# processing image 1432/2000
# processing image 1433/2000
# processing image 1434/2000
# processing image 1435/2000
# processing image 1436/2000
# processing image 1437/2000
# processing image 1438/2000
# processing image 1439/2000
# processing image 1440/2000
# processing image 1441/2000
# processing image 1442/2000
# processing image 1443/2000
# processing image 1444/2000
# processing image 1445/2000
# processing image 1446/2000
# processing image 1447/2000
# processing image 1448/2000
# processing image 1449/2000
# processing image 1450/2000
# processing image 1451/2000
# processing image 1452/2000
# processing image 1453/2000
# processing image 1454/2000
# processing image 1455/2000
# processing image 1456/2000
# processing image 1457/2000
# processing image 1458/2000
# processing image 1459/2000
# processing image 1460/2000
# processing image 1461/2000
# processing image 1462/2000
# processing image 1463/2000
# processing image 1464/2000
# processing image 1465/2000
# processing image 1466/2000
# processing image 1467/2000
# processing image 1468/2000
# processing image 1469/2000
# processing image 1470/2000
# processing image 1471/2000
# processing image 1472/2000
# processing image 1473/2000
# processing image 1474/2000
# processing image 1475/2000
# processing image 1476/2000
# processing image 1477/2000
# processing image 1478/2000
# processing image 1479/2000
# processing image 1480/2000
# processing image 1481/2000
# processing image 1482/2000
# processing image 1483/2000
# processing image 1484/2000
# processing image 1485/2000
# processing image 1486/2000
# processing image 1487/2000
# processing image 1488/2000
# processing image 1489/2000
# processing image 1490/2000
# processing image 1491/2000
# processing image 1492/2000
# processing image 1493/2000
# processing image 1494/2000
# processing image 1495/2000
# processing image 1496/2000
# processing image 1497/2000
# processing image 1498/2000
# processing image 1499/2000
# processing image 1500/2000
# processing image 1501/2000
# processing image 1502/2000
# processing image 1503/2000
# processing image 1504/2000
# processing image 1505/2000
# processing image 1506/2000
# processing image 1507/2000
# processing image 1508/2000
# processing image 1509/2000
# processing image 1510/2000
# processing image 1511/2000
# processing image 1512/2000
# processing image 1513/2000
# processing image 1514/2000
# processing image 1515/2000
# processing image 1516/2000
# processing image 1517/2000
# processing image 1518/2000
# processing image 1519/2000
# processing image 1520/2000
# processing image 1521/2000
# processing image 1522/2000
# processing image 1523/2000
# processing image 1524/2000
# processing image 1525/2000
# processing image 1526/2000
# processing image 1527/2000
# processing image 1528/2000
# processing image 1529/2000
# processing image 1530/2000
# processing image 1531/2000
# processing image 1532/2000
# processing image 1533/2000
# processing image 1534/2000
# processing image 1535/2000
# processing image 1536/2000
# processing image 1537/2000
# processing image 1538/2000
# processing image 1539/2000
# processing image 1540/2000
# processing image 1541/2000
# processing image 1542/2000
# processing image 1543/2000
# processing image 1544/2000
# processing image 1545/2000
# processing image 1546/2000
# processing image 1547/2000
# processing image 1548/2000
# processing image 1549/2000
# processing image 1550/2000
# processing image 1551/2000
# processing image 1552/2000
# processing image 1553/2000
# processing image 1554/2000
# processing image 1555/2000
# processing image 1556/2000
# processing image 1557/2000
# processing image 1558/2000
# processing image 1559/2000
# processing image 1560/2000
# processing image 1561/2000
# processing image 1562/2000
# processing image 1563/2000
# processing image 1564/2000
# processing image 1565/2000
# processing image 1566/2000
# processing image 1567/2000
# processing image 1568/2000
# processing image 1569/2000
# processing image 1570/2000
# processing image 1571/2000
# processing image 1572/2000
# processing image 1573/2000
# processing image 1574/2000
# processing image 1575/2000
# processing image 1576/2000
# processing image 1577/2000
# processing image 1578/2000
# processing image 1579/2000
# processing image 1580/2000
# processing image 1581/2000
# processing image 1582/2000
# processing image 1583/2000
# processing image 1584/2000
# processing image 1585/2000
# processing image 1586/2000
# processing image 1587/2000
# processing image 1588/2000
# processing image 1589/2000
# processing image 1590/2000
# processing image 1591/2000
# processing image 1592/2000
# processing image 1593/2000
# processing image 1594/2000
# processing image 1595/2000
# processing image 1596/2000
# processing image 1597/2000
# processing image 1598/2000
# processing image 1599/2000
# processing image 1600/2000
# processing image 1601/2000
# processing image 1602/2000
# processing image 1603/2000
# processing image 1604/2000
# processing image 1605/2000
# processing image 1606/2000
# processing image 1607/2000
# processing image 1608/2000
# processing image 1609/2000
# processing image 1610/2000
# processing image 1611/2000
# processing image 1612/2000
# processing image 1613/2000
# processing image 1614/2000
# processing image 1615/2000
# processing image 1616/2000
# processing image 1617/2000
# processing image 1618/2000
# processing image 1619/2000
# processing image 1620/2000
# processing image 1621/2000
# processing image 1622/2000
# processing image 1623/2000
# processing image 1624/2000
# processing image 1625/2000
# processing image 1626/2000
# processing image 1627/2000
# processing image 1628/2000
# processing image 1629/2000
# processing image 1630/2000
# processing image 1631/2000
# processing image 1632/2000
# processing image 1633/2000
# processing image 1634/2000
# processing image 1635/2000
# processing image 1636/2000
# processing image 1637/2000
# processing image 1638/2000
# processing image 1639/2000
# processing image 1640/2000
# processing image 1641/2000
# processing image 1642/2000
# processing image 1643/2000
# processing image 1644/2000
# processing image 1645/2000
# processing image 1646/2000
# processing image 1647/2000
# processing image 1648/2000
# processing image 1649/2000
# processing image 1650/2000
# processing image 1651/2000
# processing image 1652/2000
# processing image 1653/2000
# processing image 1654/2000
# processing image 1655/2000
# processing image 1656/2000
# processing image 1657/2000
# processing image 1658/2000
# processing image 1659/2000
# processing image 1660/2000
# processing image 1661/2000
# processing image 1662/2000
# processing image 1663/2000
# processing image 1664/2000
# processing image 1665/2000
# processing image 1666/2000
# processing image 1667/2000
# processing image 1668/2000
# processing image 1669/2000
# processing image 1670/2000
# processing image 1671/2000
# processing image 1672/2000
# processing image 1673/2000
# processing image 1674/2000
# processing image 1675/2000
# processing image 1676/2000
# processing image 1677/2000
# processing image 1678/2000
# processing image 1679/2000
# processing image 1680/2000
# processing image 1681/2000
# processing image 1682/2000
# processing image 1683/2000
# processing image 1684/2000
# processing image 1685/2000
# processing image 1686/2000
# processing image 1687/2000
# processing image 1688/2000
# processing image 1689/2000
# processing image 1690/2000
# processing image 1691/2000
# processing image 1692/2000
# processing image 1693/2000
# processing image 1694/2000
# processing image 1695/2000
# processing image 1696/2000
# processing image 1697/2000
# processing image 1698/2000
# processing image 1699/2000
# processing image 1700/2000
# processing image 1701/2000
# processing image 1702/2000
# processing image 1703/2000
# processing image 1704/2000
# processing image 1705/2000
# processing image 1706/2000
# processing image 1707/2000
# processing image 1708/2000
# processing image 1709/2000
# processing image 1710/2000
# processing image 1711/2000
# processing image 1712/2000
# processing image 1713/2000
# processing image 1714/2000
# processing image 1715/2000
# processing image 1716/2000
# processing image 1717/2000
# processing image 1718/2000
# processing image 1719/2000
# processing image 1720/2000
# processing image 1721/2000
# processing image 1722/2000
# processing image 1723/2000
# processing image 1724/2000
# processing image 1725/2000
# processing image 1726/2000
# processing image 1727/2000
# processing image 1728/2000
# processing image 1729/2000
# processing image 1730/2000
# processing image 1731/2000
# processing image 1732/2000
# processing image 1733/2000
# processing image 1734/2000
# processing image 1735/2000
# processing image 1736/2000
# processing image 1737/2000
# processing image 1738/2000
# processing image 1739/2000
# processing image 1740/2000
# processing image 1741/2000
# processing image 1742/2000
# processing image 1743/2000
# processing image 1744/2000
# processing image 1745/2000
# processing image 1746/2000
# processing image 1747/2000
# processing image 1748/2000
# processing image 1749/2000
# processing image 1750/2000
# processing image 1751/2000
# processing image 1752/2000
# processing image 1753/2000
# processing image 1754/2000
# processing image 1755/2000
# processing image 1756/2000
# processing image 1757/2000
# processing image 1758/2000
# processing image 1759/2000
# processing image 1760/2000
# processing image 1761/2000
# processing image 1762/2000
# processing image 1763/2000
# processing image 1764/2000
# processing image 1765/2000
# processing image 1766/2000
# processing image 1767/2000
# processing image 1768/2000
# processing image 1769/2000
# processing image 1770/2000
# processing image 1771/2000
# processing image 1772/2000
# processing image 1773/2000
# processing image 1774/2000
# processing image 1775/2000
# processing image 1776/2000
# processing image 1777/2000
# processing image 1778/2000
# processing image 1779/2000
# processing image 1780/2000
# processing image 1781/2000
# processing image 1782/2000
# processing image 1783/2000
# processing image 1784/2000
# processing image 1785/2000
# processing image 1786/2000
# processing image 1787/2000
# processing image 1788/2000
# processing image 1789/2000
# processing image 1790/2000
# processing image 1791/2000
# processing image 1792/2000
# processing image 1793/2000
# processing image 1794/2000
# processing image 1795/2000
# processing image 1796/2000
# processing image 1797/2000
# processing image 1798/2000
# processing image 1799/2000
# processing image 1800/2000
# processing image 1801/2000
# processing image 1802/2000
# processing image 1803/2000
# processing image 1804/2000
# processing image 1805/2000
# processing image 1806/2000
# processing image 1807/2000
# processing image 1808/2000
# processing image 1809/2000
# processing image 1810/2000
# processing image 1811/2000
# processing image 1812/2000
# processing image 1813/2000
# processing image 1814/2000
# processing image 1815/2000
# processing image 1816/2000
# processing image 1817/2000
# processing image 1818/2000
# processing image 1819/2000
# processing image 1820/2000
# processing image 1821/2000
# processing image 1822/2000
# processing image 1823/2000
# processing image 1824/2000
# processing image 1825/2000
# processing image 1826/2000
# processing image 1827/2000
# processing image 1828/2000
# processing image 1829/2000
# processing image 1830/2000
# processing image 1831/2000
# processing image 1832/2000
# processing image 1833/2000
# processing image 1834/2000
# processing image 1835/2000
# processing image 1836/2000
# processing image 1837/2000
# processing image 1838/2000
# processing image 1839/2000
# processing image 1840/2000
# processing image 1841/2000
# processing image 1842/2000
# processing image 1843/2000
# processing image 1844/2000
# processing image 1845/2000
# processing image 1846/2000
# processing image 1847/2000
# processing image 1848/2000
# processing image 1849/2000
# processing image 1850/2000
# processing image 1851/2000
# processing image 1852/2000
# processing image 1853/2000
# processing image 1854/2000
# processing image 1855/2000
# processing image 1856/2000
# processing image 1857/2000
# processing image 1858/2000
# processing image 1859/2000
# processing image 1860/2000
# processing image 1861/2000
# processing image 1862/2000
# processing image 1863/2000
# processing image 1864/2000
# processing image 1865/2000
# processing image 1866/2000
# processing image 1867/2000
# processing image 1868/2000
# processing image 1869/2000
# processing image 1870/2000
# processing image 1871/2000
# processing image 1872/2000
# processing image 1873/2000
# processing image 1874/2000
# processing image 1875/2000
# processing image 1876/2000
# processing image 1877/2000
# processing image 1878/2000
# processing image 1879/2000
# processing image 1880/2000
# processing image 1881/2000
# processing image 1882/2000
# processing image 1883/2000
# processing image 1884/2000
# processing image 1885/2000
# processing image 1886/2000
# processing image 1887/2000
# processing image 1888/2000
# processing image 1889/2000
# processing image 1890/2000
# processing image 1891/2000
# processing image 1892/2000
# processing image 1893/2000
# processing image 1894/2000
# processing image 1895/2000
# processing image 1896/2000
# processing image 1897/2000
# processing image 1898/2000
# processing image 1899/2000
# processing image 1900/2000
# processing image 1901/2000
# processing image 1902/2000
# processing image 1903/2000
# processing image 1904/2000
# processing image 1905/2000
# processing image 1906/2000
# processing image 1907/2000
# processing image 1908/2000
# processing image 1909/2000
# processing image 1910/2000
# processing image 1911/2000
# processing image 1912/2000
# processing image 1913/2000
# processing image 1914/2000
# processing image 1915/2000
# processing image 1916/2000
# processing image 1917/2000
# processing image 1918/2000
# processing image 1919/2000
# processing image 1920/2000
# processing image 1921/2000
# processing image 1922/2000
# processing image 1923/2000
# processing image 1924/2000
# processing image 1925/2000
# processing image 1926/2000
# processing image 1927/2000
# processing image 1928/2000
# processing image 1929/2000
# processing image 1930/2000
# processing image 1931/2000
# processing image 1932/2000
# processing image 1933/2000
# processing image 1934/2000
# processing image 1935/2000
# processing image 1936/2000
# processing image 1937/2000
# processing image 1938/2000
# processing image 1939/2000
# processing image 1940/2000
# processing image 1941/2000
# processing image 1942/2000
# processing image 1943/2000
# processing image 1944/2000
# processing image 1945/2000
# processing image 1946/2000
# processing image 1947/2000
# processing image 1948/2000
# processing image 1949/2000
# processing image 1950/2000
# processing image 1951/2000
# processing image 1952/2000
# processing image 1953/2000
# processing image 1954/2000
# processing image 1955/2000
# processing image 1956/2000
# processing image 1957/2000
# processing image 1958/2000
# processing image 1959/2000
# processing image 1960/2000
# processing image 1961/2000
# processing image 1962/2000
# processing image 1963/2000
# processing image 1964/2000
# processing image 1965/2000
# processing image 1966/2000
# processing image 1967/2000
# processing image 1968/2000
# processing image 1969/2000
# processing image 1970/2000
# processing image 1971/2000
# processing image 1972/2000
# processing image 1973/2000
# processing image 1974/2000
# processing image 1975/2000
# processing image 1976/2000
# processing image 1977/2000
# processing image 1978/2000
# processing image 1979/2000
# processing image 1980/2000
# processing image 1981/2000
# processing image 1982/2000
# processing image 1983/2000
# processing image 1984/2000
# processing image 1985/2000
# processing image 1986/2000
# processing image 1987/2000
# processing image 1988/2000
# processing image 1989/2000
# processing image 1990/2000
# processing image 1991/2000
# processing image 1992/2000
# processing image 1993/2000
# processing image 1994/2000
# processing image 1995/2000
# processing image 1996/2000
# processing image 1997/2000
# processing image 1998/2000
# processing image 1999/2000
# processing image 2000/2000

# %%
letter_folder = 'extracted_letters'

#creating empty lists for storing image data and labels
data = []
labels = []
for image in paths.list_images(letter_folder):
    img = cv2.imread(image)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    img = cv2.resize(img, (30,30))
    
    # adding a 3rd dimension to the image
    img = np.expand_dims(img, axis = 2)
    
    #grabing the name of the letter based on the folder it is present in
    label = image.split(os.path.sep)[-2]
    
    # appending to the empty lists
    data.append(img)
    labels.append(label)

#converting data and labels to np array
data = np.array(data, dtype = "float")
labels = np.array(labels)

# %%
#scaling the values of  data between 0 and 1
data = data/255.0

# Split the training data into separate train and test sets
from sklearn.model_selection import train_test_split
(train_x, val_x, train_y, val_y) = train_test_split(data, labels, test_size=0.2, random_state=0)

#one hot encoding
from sklearn.preprocessing import LabelBinarizer
lb = LabelBinarizer().fit(train_y)
train_y = lb.transform(train_y)
val_y = lb.transform(val_y)

# %%
from keras.models import Sequential
from keras.layers.convolutional import Conv2D, MaxPooling2D
from keras.layers.core import Flatten, Dense, Dropout
from keras.callbacks import EarlyStopping

#building model
model = Sequential()
model.add(Conv2D(20, (5, 5), padding="same", input_shape=(30, 30, 1), activation="relu"))
model.add(MaxPooling2D(pool_size=(5, 5), strides=(5, 5)))
model.add(Conv2D(50, (5, 5), padding="same", activation="relu"))
model.add(MaxPooling2D(pool_size=(5, 5), strides=(5, 5)))


model.add(Flatten())
model.add(Dense(80, activation="relu"))

model.add(Dropout(0.3))
model.add(Dense(26, activation="softmax"))

model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])

# using early stoping for avoiding overfitting
estop = EarlyStopping(patience=10, mode='min', min_delta=0.001, monitor='val_loss')

model.fit(train_x, train_y, validation_data=(val_x, val_y), batch_size=32, epochs=30, verbose=1, callbacks = [estop])
model.save('my_model.h5')
# Out:
# Using TensorFlow backend.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-6878c392b464> in <module>
# ----> 1 from keras.models import Sequential
#       2 from keras.layers.convolutional import Conv2D, MaxPooling2D
#       3 from keras.layers.core import Flatten, Dense, Dropout
#       4 from keras.callbacks import EarlyStopping
#       5
#
# C:\tools\Anaconda3\lib\site-packages\keras\__init__.py in <module>
#       1 from __future__ import absolute_import
#       2
# ----> 3 from . import utils
#       4 from . import activations
#       5 from . import applications
#
# C:\tools\Anaconda3\lib\site-packages\keras\utils\__init__.py in <module>
#       4 from . import data_utils
#       5 from . import io_utils
# ----> 6 from . import conv_utils
#       7 from . import losses_utils
#       8 from . import metrics_utils
#
# C:\tools\Anaconda3\lib\site-packages\keras\utils\conv_utils.py in <module>
#       7 from six.moves import range
#       8 import numpy as np
# ----> 9 from .. import backend as K
#      10
#      11
#
# C:\tools\Anaconda3\lib\site-packages\keras\backend\__init__.py in <module>
# ----> 1 from .load_backend import epsilon
#       2 from .load_backend import set_epsilon
#       3 from .load_backend import floatx
#       4 from .load_backend import set_floatx
#       5 from .load_backend import cast_to_floatx
#
# C:\tools\Anaconda3\lib\site-packages\keras\backend\load_backend.py in <module>
#      88 elif _BACKEND == 'tensorflow':
#      89     sys.stderr.write('Using TensorFlow backend.\n')
# ---> 90     from .tensorflow_backend import *
#      91 else:
#      92     # Try and load external backend.
#
# C:\tools\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py in <module>
#       3 from __future__ import print_function
#       4
# ----> 5 import tensorflow as tf
#       6 from tensorflow.python.eager import context
#       7 from tensorflow.python.framework import device as tfdev
#
# C:\tools\Anaconda3\lib\site-packages\tensorflow\__init__.py in <module>
#      32
#      33 # pylint: disable=g-bad-import-order
# ---> 34 from tensorflow.python import pywrap_tensorflow  # pylint: disable=unused-import
#      35 from tensorflow.python.tools import module_util as _module_util
#      36
#
# C:\tools\Anaconda3\lib\site-packages\tensorflow\python\__init__.py in <module>
#      81 from tensorflow.python import data
#      82 from tensorflow.python import distribute
# ---> 83 from tensorflow.python import keras
#      84 from tensorflow.python.feature_column import feature_column_lib as feature_column
#      85 from tensorflow.python.layers import layers
#
# C:\tools\Anaconda3\lib\site-packages\tensorflow\python\keras\__init__.py in <module>
#      24 from tensorflow.python import tf2
#      25
# ---> 26 from tensorflow.python.keras import activations
#      27 from tensorflow.python.keras import applications
#      28 from tensorflow.python.keras import backend
#
# C:\tools\Anaconda3\lib\site-packages\tensorflow\python\keras\activations.py in <module>
#      22
#      23 from tensorflow.python.keras import backend as K
# ---> 24 from tensorflow.python.keras.utils.generic_utils import deserialize_keras_object
#      25 from tensorflow.python.ops import math_ops
#      26 from tensorflow.python.ops import nn
#
# C:\tools\Anaconda3\lib\site-packages\tensorflow\python\keras\utils\__init__.py in <module>
#      37 from tensorflow.python.keras.utils.layer_utils import print_summary
#      38 from tensorflow.python.keras.utils.losses_utils import squeeze_or_expand_dimensions
# ---> 39 from tensorflow.python.keras.utils.multi_gpu_utils import multi_gpu_model
#      40 from tensorflow.python.keras.utils.np_utils import normalize
#      41 from tensorflow.python.keras.utils.np_utils import to_categorical
#
# C:\tools\Anaconda3\lib\site-packages\tensorflow\python\keras\utils\multi_gpu_utils.py in <module>
#      20 from tensorflow.python.framework import ops
#      21 from tensorflow.python.keras import backend as K
# ---> 22 from tensorflow.python.keras.engine.training import Model
#      23 from tensorflow.python.ops import array_ops
#      24 from tensorflow.python.util.tf_export import keras_export
#
# C:\tools\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py in <module>
#      38 from tensorflow.python.keras import optimizers
#      39 from tensorflow.python.keras.distribute import distributed_training_utils
# ---> 40 from tensorflow.python.keras.engine import network
#      41 from tensorflow.python.keras.engine import training_arrays
#      42 from tensorflow.python.keras.engine import training_distributed
#
# C:\tools\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\network.py in <module>
#      37 from tensorflow.python.keras import backend
#      38 from tensorflow.python.keras import callbacks
# ---> 39 from tensorflow.python.keras import saving
#      40 from tensorflow.python.keras.engine import base_layer
#      41 from tensorflow.python.keras.engine import base_layer_utils
#
# C:\tools\Anaconda3\lib\site-packages\tensorflow\python\keras\saving\__init__.py in <module>
#      18 from __future__ import print_function
#      19
# ---> 20 from tensorflow.python.keras.saving.hdf5_format import load_attributes_from_hdf5_group
#      21 from tensorflow.python.keras.saving.hdf5_format import load_model_from_hdf5
#      22 from tensorflow.python.keras.saving.hdf5_format import load_weights_from_hdf5_group
#
# C:\tools\Anaconda3\lib\importlib\_bootstrap.py in _find_and_load(name, import_)
#
# C:\tools\Anaconda3\lib\importlib\_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# C:\tools\Anaconda3\lib\importlib\_bootstrap.py in _load_unlocked(spec)
#
# C:\tools\Anaconda3\lib\importlib\_bootstrap_external.py in exec_module(self, module)
#
# C:\tools\Anaconda3\lib\importlib\_bootstrap_external.py in get_code(self, fullname)
#
# C:\tools\Anaconda3\lib\importlib\_bootstrap_external.py in get_data(self, path)
#
# KeyboardInterrupt:

# %%
import talos as ta
from keras.models import Sequential
from keras.layers import Dense

def minimal():

    x, y = ta.templates.datasets.iris()

    p = {'activation':['relu', 'elu'],
         'optimizer': ['Nadam', 'Adam'],
         'losses': ['logcosh'],
         'hidden_layers':[0, 1, 2],
         'batch_size': [20,30,40],
         'epochs': [10,20]}

    def iris_model(x_train, y_train, x_val, y_val, params):

        model = Sequential()
        model.add(Dense(32, input_dim=4, activation=params['activation']))
        model.add(Dense(3, activation='softmax'))
        model.compile(optimizer=params['optimizer'], loss=params['losses'])

        out = model.fit(x_train, y_train,
                         batch_size=params['batch_size'],
                         epochs=params['epochs'],
                         validation_data=[x_val, y_val],
                         verbose=0)

        return out, model

    scan_object = ta.Scan(x, y, params=p, model=iris_model, experiment_name="minimal_iris", fraction_limit=0.1)

    return scan_object
print(minimal())

# %%
print(model.summary())

# %%
image = cv2.imread('img2.png')
# gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    
# # Add some extra padding around the image
# gray = cv2.copyMakeBorder(gray, 8, 8, 8, 8, cv2.BORDER_REPLICATE)

# # threshold the image
# thresh = cv2.threshold(gray, 127, 255, cv2.THRESH_BINARY_INV, cv2.THRESH_OTSU)[1]

# # find the contours
# contours, hierarchy = cv2.findContours(thresh.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
hsv = cv.cvtColor(image, cv.COLOR_BGR2HSV)
lower_red = np.array([0,0,150])
upper_red = np.array([255,255,255])
# Load the image and convert it to grayscale
#     image = cv2.imread(captcha)
#     gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
mask = cv.inRange(hsv, lower_red, upper_red)
imCopy = mask.copy()
imCopy=~imCopy
#     # Add some extra padding around the image
#     gray = cv2.copyMakeBorder(gray, 8, 8, 8, 8, cv2.BORDER_REPLICATE)

#     # applying threshold
#     thresh = cv2.threshold(gray, 127, 255, cv2.THRESH_BINARY_INV, cv2.THRESH_OTSU)[1]
contours,hierarchy= cv.findContours(imCopy, cv.RETR_EXTERNAL, cv.CHAIN_APPROX_NONE)[-2:]


    
letter_image_regions = []

# Now we can loop through each of the contours and extract the letter

for contour in contours:
    # Get the rectangle that contains the contour
    (x, y, w, h) = cv2.boundingRect(contour)
    
    # checking if any counter is too wide
    # if countour is too wide then there could be two letters joined together or are very close to each other
    if w / h > 1.5:
        # Split it in half into two letter regions
        half_width = int(w / 2)
        letter_image_regions.append((x, y, half_width, h))
        letter_image_regions.append((x + half_width, y, half_width, h))
    else:
        letter_image_regions.append((x, y, w, h))
            

# Sort the detected letter images based on the x coordinate to make sure
# we get them from left-to-right so that we match the right image with the right letter  

letter_image_regions = sorted(letter_image_regions, key=lambda x: x[0])

# Create an output image and a list to hold our predicted letters
output = cv2.merge([mask] * 3)
predictions = []
    
# Creating an empty list for storing predicted letters
predictions = []
    
# Save out each letter as a single image
for letter_bounding_box in letter_image_regions:
    # Grab the coordinates of the letter in the image
    x, y, w, h = letter_bounding_box

    # Extract the letter from the original image with a 2-pixel margin around the edge
    letter_image = mask[y - 2:y + h + 2, x - 2:x + w + 2]

    letter_image = cv2.resize(letter_image, (30,30))
        
    # Turn the single image into a 4d list of images
    letter_image = np.expand_dims(letter_image, axis=2)
    letter_image = np.expand_dims(letter_image, axis=0)

    # making prediction
    pred = model.predict(letter_image)
        
    # Convert the one-hot-encoded prediction back to a normal letter
    letter = lb.inverse_transform(pred)[0]
    predictions.append(letter)


    # draw the prediction on the output image
    cv2.rectangle(output, (x - 2, y - 2), (x + w + 4, y + h + 4), (0, 255, 0), 1)
    cv2.putText(output, letter, (x - 5, y - 5), cv2.FONT_HERSHEY_SIMPLEX, 0.55, (0, 255, 0), 2)

# Print the captcha's text
captcha_text = "".join(predictions)
print("CAPTCHA text is: {}".format(captcha_text))

# Show the annotated image
cv2.imshow('output',output)
cv2.waitKey(0)

# %%
import tensorflow as tf
print(tf.__version__)
